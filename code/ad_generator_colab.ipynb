# %% [markdown]
# # Capstone: Generating Ad text for Amazon shopping

# %% [markdown]
# ### **Problem Satatement**

# %% [markdown]
# ### Contents:
# - [Problem Statement](#Problem-Statement)
# - [Summary](#Summary)
# - [Data Dictionary](#Data-Dictionary)
# - [Methodology](#Methodology)
# - [Findings and Observations](#Findings-and-Observations)
# - [Cross-Post](#Cross-Post)
# - [Best Models](#Best-Models)
# - [Conclusions](#Conclusions)
# - [Next Steps](#Next-Steps)
# - [Bibliography](#Bibliography)
#
#
# #### Problem Statement<a class="anchor" id="Problem-Statement"></a>
#
# Amazon’s 6 million Sellers want to generate creative and fresh ads quickly and efficiently to promote their products on the Amazon web site. Current methods require much manual creation of the advertisement text and it is cumbersome for large Sellers who have many thousands of listed products. Fast moving items like consumer electronics are updated frequently and the ads need to be updated equally quickly.
#
# This is a large business opportunity and a few startups have begun using Natural Language Generation (NLG) technology to auto-generate text including Ads. The model can be easily fine-tuned for Ads for Google, Facebook, Bing and other e-commerce platforms, as well as many sentence completion applications like Quora Question Answer, personalised review generator, email subject lines and other marketing content. These GPT models also do a decent job in writing code!
#
# An AI startup has asked me to come up with a pilot project.
#
# #### Summary<a class="anchor" id="Summary"></a>
# Given that State of the Art models like OpenAI's GPT3 and EleutherAI's GPT-NEOs are trained on billions of parameters and cost upwards of $10M to train, how good can our RNN LSTM model really be?
# How much data is sufficient and what e-commerce verticals work best?
# How does the model compare with these Large Language models?
# Can we use our dataset to fine-tune these pre-trained models?
# How well does our fine-tuned model perform?
# What metrics can be used to evaluate the model?
#
# Using advertisement data for Amazon Ads
# 2 domains
# add holiday text

# %% [markdown]
# #### Data Dictionary<a class="anchor" id="Data-Dictionary"></a>
#
# <https://www.kaggle.com/datasets/sachsene/amazons-advertisements> from <https://github.com/paschok/Diploma>
#
# The dataset size is 252 MB and comprises of 2.7 million ad texts (each is one row in the csv) in 445 files across 40 categories like electronics, wearables, automotive, appliances, fashion, tools, accessories etc.
#
# #### Input Data
# Decided to use only 2 domains (electronics and wearables) since I could only use about 10-15K rows of training data without running into resource constraints.
#
# * [`amazon_tv_wearable_12k_holidays.csv`](../data/amazon_tv_wearable_12k_holidays.csv): Ad text data from amazon.com shopping
#
# **Samples of ad text:**
#
# Sony SWR50 SmartWatch 3 Transflective Display Watch [Black]
# Sony SmartWatch US version 1 Android Bluetooth USB Retail Box
# Sony HDRAS20/B Action Video Camera
# Sony DVPSR510H DVD Player, with HDMI port (Upscaling)
# Sony UBP-X700 4K Ultra HD Blu-Ray Player
# Sony STRDH590 5.2 multi-channel 4k HDR AV Receiver with Bluetooth
# Sony BDPS3700 Streaming Blu-Ray Disc Player with Wi-Fi (Black)
# Apple Watch Series 3 (GPS), 42mm Space Gray Aluminum Case with Black Sport Band - MQL12LL/A (Renewed)
# Apple Watch Series 4 (GPS + Cellular, 40mm) - Gold Aluminium Case with Pink Sand Sport Band (Renewed)
# Apple Watch Screen Protector [2 Pack] Premium 3D Tempered Glass Screen Protector for iWatch 42mm Series 3 2 1-[Full Coverage][HD Clear][Scratch-Resistant][Anti Bubble]
# Samsung Gear S2 Smartwatch - Dark Gray
# Samsung HMD Odyssey+ Windows Mixed Reality Headset with 2 Wireless Controllers 3.5" Black (XE800ZBA-HC1US)
# Samsung Galaxy Watch (42mm) Smartwatch (Bluetooth) Android/iOS Compatible -SM-R810 (Rose Gold)
# Samsung Galaxy Fit Black (Bluetooth), SM-R370NZKAXAR ‚Äì US Version with Warranty
# Samsung Galaxy Smartwatch (46mm) Silver (Bluetooth), SM-R800NZSAXAR ‚Äì US Version with Warranty
# GE Universal Remote Control for Samsung, Vizio, LG, Sony, Sharp, Roku, Apple TV, RCA, Panasonic, Smart TVs, Streaming Players, Blu-ray, DVD, Simple Setup, 4-Device, Graphite, 33711
# Dell Mobile Projector M318WL 500 ANSI lumens WXGA (1280 x 800) 16:10
# Full Motion Tilt, Pan, Swivel Desktop Mount for 32" Samsung, LG, Dell, ViewSonic, HP LED TV/Monitor
# Casio WSD-F10 Smart Outdoor Watch
# Casio Men's 'Pro Trek' Resin Outdoor Smartwatch, Color:Orange (Model: WSD-F20-RGBAU)
# [5-Pack] For Casio GST-B100 Watch Screen Protector,Full Coverage Screen Protector for GST-B100 / GST-B100-1ACR/GST-B100X-1AJF/GST-B100D-1ACR HD Clear Anti-Bubble and Anti-Scratch
# AmazonBasics USB 3.0 to 10/100/1000 Gigabit Ethernet Internet Adapter
# AmazonBasics Amplified Indoor/Outdoor TV Antenna - 60 Mile Range
# AmazonBasics TV Trolley for 24-43" TVs with Swivel Feature
# NVIDIA SHIELD TV Gaming Edition | 4K HDR Streaming Media Player with GeForce NOW
# Geekworm NVIDIA Jetson Nano WiFi Adapter Dual Band Wireless USB 3.0 Adapter 5GHz and 2.4GHz 1200Mbps Network Card
#
#
# #### Intermediate Data files
#
# To provide a cleaner break between the different facets of modeling and to permit simpler navigation across notebooks, I created a number of intermediate files. These files are used in the model training and evaluation in notebooks 2 and 3.
#
# **Model evaluation metrics**
#
# * [`lstm_results_df.csv`](../data/lstm_results_df.csv): Ad text data from amazon.com

# %% [markdown]
# #### Output Data files
#
# * [`pytorch_model.bin`](../data/AdTextGenerator/pytorch_model.bin): Model fine-tuned on the amazon ads dataset on top of the pre-trained EleutherAI/gpt-neo-125M model.
#
#
# Published my model to the open-source “GitHub of machine learning” HuggingFace -  <a href="https://huggingface.co/nirajsaran/AdTextGenerator" target="_blank">My AdTextGenerator</a> for interactive online ad text generation or use by others for further downstream fine-tuning.
#
# * [`config.json`](../data/AdTextGenerator/config.json): Config file for the above
#
# * [`lstm_model_13krows_batch4k.h5`](../data/lstm_model_13krows_batch4k.h5): My trained RNN LSTM model
# * [`lstm_model_emb_13k_batch4k.h5`](../data/lstm_model_emb_13k_batch4k.h5): My trained model with embedding layer
#
#
# #### Image files
# For presentation purposes

# %% [markdown]
# ### Outside Research
# Word Level text generation using RNN LSTM.
# Fine-tuning a pre-trained model on Google Colab with GPU.
# Uploading a model to HuggingFace and customizing the model-card for model parameters and example texts.

# %% [markdown]
# ### The notebook can be run on the local machine or on Google Colab. Set the global variables accordingly

# %%
# Set global variables 
# Set to True if using Google colab or set to False if using the local machine
onGoogleColab = True

# Separate variable if using GPU on Colab because the GPU is not always available and is not needed 
# if the model is already trained and being used for inference
useGPU = True # set to False if using local machine

# Use TPU 
useTPU = False 

max_rows= 15000 # limit the number of input observations to avoid going Out Of Memory (OOM) 
batch_size = 4096 # Tried various batch_sizes from 256 upto 4k. 4k gives the least loss but requires the most memory
layer_size = 128

# %%
# Mount Google Drive. Pops up an authentication window. Connect your Google account and grant permissions. 
# This is not needed for local machine
if onGoogleColab: 

  from google.colab import drive
  drive.mount('/content/drive')
  # %cd drive/MyDrive/Colab\ Notebooks/nlg/code
  # %pwd
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/nlg/code

# %%
if onGoogleColab:
  # !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.19.2-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 5.2 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.6.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 3.0 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 49.5 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 40.8 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.6.0 pyyaml-6.0 tokenizers-0.12.1 transformers-4.19.2

# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import datetime as dt
#import re

from preprocess_tokenize import * # helper .py file
from modeling_functions import * # helper .py file
#from collections import Counter

import tensorflow as tf

from tensorflow.keras.utils import Sequence 

#from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.layers import Dense, Dropout, LSTM, Embedding

#from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential

#from tensorflow.keras.callbacks import EarlyStopping

from transformers import pipeline

# %% [markdown]
# #### Read input data from the amazon ad text file.
# This contains data from Amazon ads for two categories Electronics and Wearables. I also added a few rows for holiday related special deals and discounts to support additional ad formats.

# %%
# Read data

file_name = "../data/amazon_tv_wearable_12k_holidays.csv"

df_ads = pd.read_csv(file_name)

df_ads.head() # contains just one column
# Out:
#                                                   ad
# 0  Spigen Rugged Armor Pro Designed for Apple Wat...
# 1                                   Xiaomi Mi Band 4
# 2  LK 6 Pack Screen Protector for Apple Watch (38...
# 3  KOLEK Floral Bands Compatible with Apple Watch...
# 4  Amazfit Bip Smartwatch by Huami with All-Day H...

# %%
df_ads.describe()
# Out:
#                          ad
# count                 13070
# unique                12880
# top     Holiday specials on
# freq                     13

# %% [markdown]
# ### Data Cleanup
# - only nulls and dups needed to be cleaned up

# %%
df_ads.dropna(inplace=True) # drop the nulls, if any

# %%
df_ads.loc[df_ads["ad"].str.contains("Casio")].head()
# Out:
#                                                      ad
# 1882  Casio Men's 'Pro Trek' Resin Outdoor Smartwatc...
# 2265  [5-Pack] For Casio DW-5600 /DW5600 Watch Scree...
# 2699  [5-Pack] for Casio MDV106-1A Watch Screen Prot...
# 2968  23mm Rubber Watch Band Strap Fits Casio Replac...
# 3268  SIKAI Protective Bumper for Casio G-Shock GW56...

# %%
len( set( df_ads["ad"] ) ) # 12880 unique rows out of 13070
# Out:
# 12880

# %%
# Remove the dups and store back in df
df_ads = pd.DataFrame(list( set( df_ads["ad"] ) ), columns = ["ad"] )
df_ads.head()
# Out:
#                                                   ad
# 0  Henva Slim Band Compatible with Apple Watch 38...
# 1  Secbolt Bling Bands Compatible Apple Watch Ban...
# 2  SWEES Leather Bands Compatible Fitbit Charge 3...
# 3  4 Channel Wireless Bluetooth Amplifier - 3000 ...
# 4  Replaced Remote Control Compatible for Samsung...

# %% [markdown]
# #### EDA
#
# - Only one column of information

# %%
# Look at the data

plt.hist([len(s) for s in df_ads["ad"]]);
plt.title("Frequency of number of characters per ad")
# Out:
# Text(0.5, 1.0, 'Frequency of number of characters per ad')

# %%
# add column with len of ad text

df_ads["num_chars"] = [len(s) for s in df_ads["ad"]]

df_ads['num_chars'].head()
# Out:
# 0    200
# 1    170
# 2    197
# 3    196
# 4    130
# Name: num_chars, dtype: int64

# %%
df_ads['num_chars'].describe()
# Out:
# count    12880.000000
# mean       140.190295
# std         51.297043
# min          6.000000
# 25%        105.000000
# 50%        152.000000
# 75%        183.000000
# max        896.000000
# Name: num_chars, dtype: float64

# %%
df_ads['num_chars'].value_counts()
# Out:
# 198    272
# 199    270
# 200    268
# 197    237
# 196    205
#       ...
# 246      1
# 896      1
# 433      1
# 325      1
# 245      1
# Name: num_chars, Length: 229, dtype: int64

# %%
# See long ads
pd.set_option ('display.max_colwidth', 350) 

df_ads.loc[df_ads['num_chars'] > 300]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                   ad  \
# 7      LG Electronics AN-MR400G/H Magic Motion Remote Control with Browser Wheel for 2013 Year Smart Tvs (Worldwide use, English Keypad) also known as ANMR400. The TV remote AN-MR400 is compatible with the following LG Smart TV series.2013 LED LCD Smart TVs: 42LA6650, 47LA6900, 47LA7400, 50LA6900, 55LA6205, 55LA6900, 55LA7400, 60LA7400, EA9800, LA9700...
# 648    Brand NEW Original OLEVIA RC-LTL RCLTL Remote for 219H 226T 226V 227V 232S 232V 237T 237V 242V 247T OLEVIA 232-T12 OLEVIA 232S OLEVIA 232V OLEVIA 237-S11 OLEVIA 237-T11 OLEVIA 237-T12 OLEVIA 237T OLEVIA 237V OLEVIA 242FHDTV OLEVIA 242TFHD OLEVIA 242V OLEVIA 242V78650 OLEVIA 247T OLEVIA 247TFHD OLEVIA 252T OLEVIA 255T OLEVIA 265T OLEVIA 265TFHD ...
# 822    NEW Remote fit for VIZIO E320i-B0 E390i-A1 E401i-A2 E480i-B2 E470i-A0 E480-B2 E500D-A0 E291IA1 E320IB0 E390IA1 E401IA2 E550I-B2 E470i-A0 E480IB2 E500DA0 E500I-A1 E550I-A0 E420I-A0 E390I-A1 E320I-A0 E241I-A1 E470I-A0-B E420I-A0-B E390I-A1B E241I-A1B E500I-B1E E420i-A0 E320i-A0 E320I-A2 E322AR E422AR E502AR and most App internet LCD and LED TV---...
# 2488                           Original TV remote control for LG 3D AKB73615362=AKB73615397 *UNIVERSAL* 100% replacement for AKB73615303, AKB73615397 and AKB73756542. HIGH QUALITY Remote. It is a perfect solution if you dont want to use LG MAGIC AN-MR400 remote. Suitable models: AKB73615303, AKB73615362, AKB73615302, AKB73756542, AKB73615361, AKB73615362
# 2927   New Sharp GA600WJSA GA362WJSA GA416WJSB Replace AQUOS TV Remote Control Sub GA242WJSA, GA263WJSA, GA264WJSA, GA331WJSA, GA363WJSA, GA384WJSA, GA414WJSA, GA415WJSA, GA416WJSA, GA425WJSA, GA468WJSA, GA484WJSA, GA535WJSA, GA549WJSA, GA551WJSA, GA648WJSA, GA669WJSA, GA678WJSA, GA724WJSA GA425WJSA GA363WJSA GA331WJSA GA384WJSARRMCGA600WJSA GA600WJSA...
# 4372                                              Brand NEW original seiki SEIKI TV Remote for SEIKI LC-32GC12F LC-46G68 SC552GS SC324FB SC32HT04 SE32HS01 SE65FY18 SE60GY24 SE65JY25 SE19HT01 SE40FY19 SE50UY04 LE-46GCA LE-55G77E SE39UY04 SE47FY19 LE-32SCL-C SE55UY04 SC22HY07 TV REMOTE----Original remote; do not any setting, only put into battery can work!
# 5568   Brand New Genuine VIZIO smart TV remote XRT510 for all VIZIO M-series Smart internet App TV such as: M701D-A3R M651D-A2R M601D-A3R M321i-A2 M321iA2 M401i-A3 M401iA3 M471i-A2 M471iA2 M501D-A2 M501DA2 M501D-A2R M501DA2R M551D-A2 M551DA2 M551D-A2R M551DA2R M601D-A3 M601DA3 M601D-A3R M601DA3R M651D-A2 M651DA2 M651D-A2R M651DA2R M701D-A3 M701DA3 M70...
# 6745   New ELEMENT TV Remote for ELDFW406 ELCFT262 ELDFW322 ELCFW326 ELCFW329 ELDFT404 ELCFW328 ELDFW464 ELDFT465J ELDFQ501J ELEFQ501J ELGFW601 ELDFW501 ELEFW193 ELEFJ191 ELEFT195 ELEFW195 ELEFS191 ELEFT193 ELEFJ243 ELEFS241 ELEFW264 ELEFT281 ELEFW325 ELEFT326 ELEFS321 ELEFJ321 ELEFT406 ELEFQ402 ELEFW401A ELEFQ462 ELEFT466 ELEFW462 ELEFC461 ELEFC463JA...
# 7122   NEW SEIKI TV Remote control for SEIKI SE55GY19 SE65UY04 SE22FE01 SE65GY25 SE40FY27 SE32FY22 TV SE24FE01-W SE19HE01 SE39HE02 LC-32G82 SE24FT01 SE20HS04 SE26HQ04 SE50FY28 SC151FS SC241FS LC24G82 LC22G82 SC221FS SC261FS SC262FS SC32HT04 SC371TS SC391TS LC-40G81 SC461TS SC501TS SC552GS SC601GS SC601US SC601TS SE131FS SE191FS SE221FS SE222FS SE22HY0...
# 7251          New RCA Replaced remote RC-RCA1 fit for RCA WD11452 WD12143 WD12372 WD11392 WD12422 WD12192 WD11442 WD12101 WD12492 WD12021 RCA 46LB45RQ LED39B45RQ 26LA30RQD 32LA30RQ 32LA30 LED42C45RQ 46LB45RQ 46LB45RQ LED50B45RQ RE20QP80 26LARQD LED30B30RQ 40LA45RQ LED42C45 32LA30RQD LED32B30RQ LED46A55R120Q 42PA30RQ RCA RE20QP80 LCD LED TV REMOTE CONTROL
# 8570   Mount-It! MI-1121M Slim Tilt TV Wall Mount Bracket for LED LCD Plasma Flat Screen Panels for 32‚Äù to 65‚Äù (Many from 20-75‚Äù) up to VESA 600 x 400 and 130 lbs Low Profile. 0-15 Degree Forward Adjustable Tilting and Leveling Bubble Fits Samsung, Sony, LG Sharp, Insignia, Vizio, Haier 26, 28, 32, 40, 42, 48, 49, 50, 51, 52, 55, 60, 65 inch TV,...
# 10970  Brand NEW Original INSIGNIA TV remote control NS-RC4NA-14 RC4NA14 Remote For NS-28ED200NA14 NS-50D400NA14 NS-19ED200NA14 55E4400A14 NS-58E4400A14 NS-24E400NA14 NS-60E4400A14 NS-65E4400A14 NS-50L440NA14 NS-46D400NA14 NS-65D4400A14 NS-22E400NA14 NS-46L400NA14 NS-46E440NA14 NS-32E2000A14 NS-39D400NA14 NS-32DD2000A14 NS-39L400NA14 NS-55E4400A14 NS-...
#
#        num_chars
# 7            744
# 648          896
# 822          372
# 2488         325
# 2927         433
# 4372         306
# 5568         397
# 6745         470
# 7122         747
# 7251         342
# 8570         352
# 10970        426

# %%
# Create column with  number of words 

df_ads['num_words'] = [ len(s.strip().split(" ")) for s in df_ads['ad']]

# %%
df_ads.head()
# Out:
#                                                                                                                                                                                                          ad  \
# 0  Henva Slim Band Compatible with Apple Watch 38mm 40mm 42mm 44mm, Replacement Accessories Slim Wristbands with Stainless Steel Buckle for iWatch Series 5 Series 4, Series 3, Series 2, Series 1, S/M M/L
# 1                                Secbolt Bling Bands Compatible Apple Watch Band 38mm 40mm Iwatch Series 5, Series4, Series 3, Series 2, Series 1, Stainless Steel Hollowed-Out Metal Replacement Wristband
# 2     SWEES Leather Bands Compatible Fitbit Charge 3 & Charge 3 SE Fitness Tracker, Genuine Leather Band Strap Wristband Replacement for Women Men Small & Large, Black, Rose Gold, Beige, Brown, Grey, Tan
# 3      4 Channel Wireless Bluetooth Amplifier - 3000 Watt Stereo Speaker Home Audio Receiver w/FM Radio, USB, 2 Microphone w/Echo for Karaoke, Front Loading CD DVD Player, LED, Rack Mount - Pyle PD3000BA
# 4                                                                        Replaced Remote Control Compatible for Samsung UN32H5201AF UN46H6201 UN55H6203 UN40H5203AF UN50H5203AF UN58J5190AF Smart LED HD TV
#
#    num_chars  num_words
# 0        200         33
# 1        170         25
# 2        197         32
# 3        196         32
# 4        130         16

# %%
df_ads['num_words'].describe()
# Out:
# count    12880.000000
# mean        21.238898
# std          7.971833
# min          1.000000
# 25%         16.000000
# 50%         22.500000
# 75%         27.000000
# max        131.000000
# Name: num_words, dtype: float64

# %%
df_ads["num_words"].sum()  # total words in corpus: 30,994,101: 31M with the full dataset!
# Out:
# 273557

# %%
#re_text = re.sub(r"\S*\d\S*", '', joined_text).strip()
plt.plot(df_ads['num_words']);

# %% [markdown]
# ### End of EDA. Prepare for Modeling - tokenizing, mapping tokens to numeric encodings

# %% [markdown]
# #### Deciding how many documents to use has been a big challenge.
# The orginal dataset consists of 2.7 million documents (rows) and a total corpus size of 31 million words across 40 categories.
#
# Neural networks require huge amounts of compute resources for model training. Using the GPU on Google Colab was 8 times faster than my local machine, but it eventually started running Out of Memory and the session would frequently crash mid-way. The Colab Pro plan would only take me marginally further.
#
# In addition to the number of documents, the batch_size makes a difference in the time and memory required and impacts the evaluation metrics of the model. I reduced the batch_size so that the training would need less memory, but it increased the loss (categorical_crossentropy) and reduced the categorical_accuracy. Another factor was using the Embedding layer in the model architecture. This sped up the training by about 40% and the evaluation metrics were marginally worse (not sure why, yet).
#
# Of course, the number of epochs in fitting is directly proportionaly to the time taken and I picked the number that maximised the categorical_accuracy.
#
# So essentially, the variables were number of documents and batch_size and the trade-off was the accuracy of the model.
#
# I wanted to use all 2 million documents as the corpus - it would have taken me <font color="red">5 years to train the model</font> on my local machine and <font color="red">8 months on Google Colab</font>! I would have run into OOM in any case. In fact, <font color="red">at 25k documents I started running into OOM</font>.
#
# Hence, I  was able to to use only 13k (0.5%!) documents and I picked 2 categories (Electronics and Wearables) of the 40 in my Amazon dataset.
#
# The README has details on the timings and evaluation metrics for the 10K, 25K, 100K, 500K, 2M documents on both my local machine and Google Colab with GPU.
#
# I also experimented with various model parameters -
# number of nodes/neurons in the input layer, dimension of vectors in the Embedding layer, optimizer (Adam and RMSprop), numberof epochs for training, sequence length etc. I have chosen the optimal values after experimentation.

# %%
# Keep 10% of df_ads for validation data 

df_ads_test = df_ads.sample(frac = 0.1, random_state=42)
 
# Create train df by dropping the test df rows

df_ads_train = df_ads.drop(df_ads_test.index)

# %%
df_ads_train.head()
# Out:
#                                                                                                                                                                                                          ad  \
# 0  Henva Slim Band Compatible with Apple Watch 38mm 40mm 42mm 44mm, Replacement Accessories Slim Wristbands with Stainless Steel Buckle for iWatch Series 5 Series 4, Series 3, Series 2, Series 1, S/M M/L
# 1                                Secbolt Bling Bands Compatible Apple Watch Band 38mm 40mm Iwatch Series 5, Series4, Series 3, Series 2, Series 1, Stainless Steel Hollowed-Out Metal Replacement Wristband
# 2     SWEES Leather Bands Compatible Fitbit Charge 3 & Charge 3 SE Fitness Tracker, Genuine Leather Band Strap Wristband Replacement for Women Men Small & Large, Black, Rose Gold, Beige, Brown, Grey, Tan
# 3      4 Channel Wireless Bluetooth Amplifier - 3000 Watt Stereo Speaker Home Audio Receiver w/FM Radio, USB, 2 Microphone w/Echo for Karaoke, Front Loading CD DVD Player, LED, Rack Mount - Pyle PD3000BA
# 4                                                                        Replaced Remote Control Compatible for Samsung UN32H5201AF UN46H6201 UN55H6203 UN40H5203AF UN50H5203AF UN58J5190AF Smart LED HD TV
#
#    num_chars  num_words
# 0        200         33
# 1        170         25
# 2        197         32
# 3        196         32
# 4        130         16

# %%
df_ads_test.reset_index( drop = True, inplace = True)
df_ads_test.head()
# Out:
#                                                                                                                                                                              ad  \
# 0                                VIQIV for Compatible with Apple Watch Bands 38mm 40mm 42mm 44mm iWatch Series 4 3 2 1, Luxury Diamond Bracelet Metal Wristband Strap for Women
# 1           Awinner Case for Gear S3 Frontier SM-R760, Shock-Proof and Shatter-Resistant Protective Band Cover Case for Samsung Gear S3 Frontier SM-R760 Smartwatch (10-Colour)
# 2                        Android 9.0 TV Box 4GB RAM 64GB ROM, TICTID Android TV Box RK3318 Quad-Core 64bit with Dual-WiFi 5G/2.4G, BT 4.0, 4K2K UHD H.265, USB 3.0 Smart TV Box
# 3                                                     Adjustable Ceiling TV Mount Bracket Fits Most 14-42" LCD LED Plasma Monitor Flat Panel Screen Displays Tilt / 360¬∞Swivel
# 4  MoKo Compatible Band Replacement for Apple Watch 42mm 44mm Series 5/4/3/2/1, Stainless Steel Metal Replacement Smart Watch Strap Bracelet - Silver(Not Fit iWatch 38mm 40mm)
#
#    num_chars  num_words
# 0        142         25
# 1        163         22
# 2        150         28
# 3        121         19
# 4        172         25

# %%
#df_ads_test.drop(columns=['index'], inplace=True )
df_ads_test
# Out:
#                                                                                                                                                                                   ad  \
# 0                                     VIQIV for Compatible with Apple Watch Bands 38mm 40mm 42mm 44mm iWatch Series 4 3 2 1, Luxury Diamond Bracelet Metal Wristband Strap for Women
# 1                Awinner Case for Gear S3 Frontier SM-R760, Shock-Proof and Shatter-Resistant Protective Band Cover Case for Samsung Gear S3 Frontier SM-R760 Smartwatch (10-Colour)
# 2                             Android 9.0 TV Box 4GB RAM 64GB ROM, TICTID Android TV Box RK3318 Quad-Core 64bit with Dual-WiFi 5G/2.4G, BT 4.0, 4K2K UHD H.265, USB 3.0 Smart TV Box
# 3                                                          Adjustable Ceiling TV Mount Bracket Fits Most 14-42" LCD LED Plasma Monitor Flat Panel Screen Displays Tilt / 360¬∞Swivel
# 4       MoKo Compatible Band Replacement for Apple Watch 42mm 44mm Series 5/4/3/2/1, Stainless Steel Metal Replacement Smart Watch Strap Bracelet - Silver(Not Fit iWatch 38mm 40mm)
# ...                                                                                                                                                                              ...
# 1283                                                              HDMI Surge Protector, NEWPOWER Mini Portable HDMI 1.4 Protector for ESD and Surge Protection, Support HDCP - Black
# 1284                                                for Michael Kors Runway Band, Lamshaw Leather Strap Replacement Straps for Michael Kors Women's Access Runway Smartwatch (Black)
# 1285                                                     for Apple Watch 42mm, IVAPPON Men's Calfskin Leather and Nylon NATO Watch Strap Swiss-Army Style IWatch Band Regluar Length
# 1286  Gvirtue Remote Control VR2 VR4 Replacement for Vizio TV VL260M VO320E VO370M VO420E VP422 VECO320L VECO320L1A VL320M VP322 VECO320LHDTV VP422HDTV10A VP322HDTV10A VP323HDTV10A
# 1287   Rosa Schleife Compatible replacement for strap Apple Watch Series 4 40mm Series 3 38mm,Metal Wrist Bracelet Compatible Replacement Wrist Band White Apple Watch Edition Sport
#
#       num_chars  num_words
# 0           142         25
# 1           163         22
# 2           150         28
# 3           121         19
# 4           172         25
# ...         ...        ...
# 1283        114         18
# 1284        128         18
# 1285        123         19
# 1286        174         22
# 1287        173         25
#
# [1288 rows x 3 columns]

# %%
# Convert from df to string for modeling. 
# Limit to max_rows (13k) to avoid OOM

ads_str_train = df_ads_train["ad"].to_string(header= False, index=False, max_rows=max_rows) 
ads_str_test = df_ads_test["ad"].to_string(header= False, index=False, max_rows=max_rows)

# %%
# number of characters altogether: 4.5M
len(ads_str_train), len(ads_str_test)
# Out:
# (4068791, 452087)

# %%
# Check ads_str 
idx = 463575
print( ads_str_train[idx:idx+200])
# Out:
#  Wireless Support Virtual Reality Headset Glasses for iPhone,Samsung,iOS or Android Smartphones

# %%
# Find all the occurrences of Sony. Print only a few (every 20th one)
idx = 0
str_to_find = "Sony"
cnt = ads_str_train.count( str_to_find)

for i in range (cnt): 
    idx = ads_str_train.find( str_to_find, idx+1)    
    if i // 20 == 0: # limit the number printed
        print( ads_str_train[idx:idx+200])
# Out:
# Sony RDR-VX500 DVD Player/Recorder with VCR (RDRVX500)
#
# Sony DVP-SR510H Remote Control
#
# Sony BDP-BX18 BDP-S185 BDPBX3100 BDP-BX39 BDP-S1100 BLU-RAY DISC Player Subs for RMT-B119A
#
# Sony BDP-S6500 Upgraded Multi-Region Zone Free Blu-Ray DVD Player
#
# Sony Bravia TV KDL-46HX753BU kdl-40hx750 KDL-46HX750 KDL-55HX750 KDL-55HX751 KDL-46HX753BU KDL-46HX751 KDL46HX750 KDL55HX750 KDL55HX751 kdl-32hx750 kdl-46hx753
#
# Sony XBR-55X855C KDL-50W800C KDL-50W800380 KDL-50W800BUN1 LED HDTV Smart HD TV
#
# Sony BDPS3500 Blu-ray Player with Wi-Fi (2015 Model)
#
# Sony TV KDL48R510C KDL-48R510C KDL40R510C KDL-40R510C KDL32R500C KDL-32R500C KDL40R550C KDL-40R550C KDL48R550C KDL-48R550C
#
# Sony Bravia KDL-46VE5 KDL-46VL150 KDL-52S5100 KDL32L5000 KDL46S5100 KDL32XBR9 KDL52V5100 KDL46V5100 KDL52S5100 KDL32S5100 KDL40V5100 KDL26L5000
#
# Sony, Sharp, Roku, Apple TV, RCA, Panasonic, Smart TVs, Streaming Players, Blu-ray, DVD, Simple Setup, 4-Device, Graphite, 33711
#
# Sony Sound Bar Ss-wct60 Sswct60 Ht-ct60 Sact60 Sa-ct60 Sa-ct60bt Sact60bt Htct60bt Ht-ct60bt Sact60bt Sa-ct60bt Sswct60 Ss-wct60
#
# Sony DVD Player DVP-SR110 DVP-SR120 DVPSR201P DVP-SR201P DVPSR210P DVP-SR210P DVP-SR210PB DVP-SR310P DVP-SR320 DVP-SR405P DVPSR405P DVPSR510H DVP-SR510H DVP-SR750HP
#
# Sony Natural Sound Stereo Receiver Sharp Panasonic Receiver Runer Audio Systems etc
#
# Sony BDPS1500 Wired Blu-ray Player 2015 Model - (Renewed)
#
# Sony BDP-S370 Blu-ray Disc Player
#                                                                                                                                                                  Supoi
# Sony Playstation/Lenovo Explorer/Samsung Odyssey/HP/Acer/Dell Wired Virtual Reality Headset 8 Pack by Lunies
#
# Sony SLV-N71 4-Head Hi-Fi VCR
#
# Sony STR-DH550 STR-DH540B STR-DH740 STR-DH750 AV System Receiver
#
# Sony DVPSR210P DVD Player (Progressive Scan) (Renewed)
#
# Sony BDPS3700 Streaming WiFi Blu Ray Player (Renewed)

# %%
# Make sure split contains similar data - Sony occurs 22 times in test and 296 in train, so looks good
idx = 0
str_to_find = "Sony"
cnt = ads_str_test.count( str_to_find)

for i in range (cnt): 
    idx = ads_str_test.find( str_to_find, idx+1)    
    #print( ads_str_test[idx:idx+200])

# %% [markdown]
# ### For LSTM, we need to:
# (These steps happen in preprocess_tokenize.py)
# 1. Tokenize - split the ad text into tokens (words)
# 2. Remove dups - create a list of distinct tokens
# 3. Since the model needs numeric values (not words), we map the tokens into numeric ids (used a simple index in the list as the ids).
# (The Keras Embedding layer does a semantics vectorization of the tokens, more later).
# And we maintain a dict to map the ids back into the tokens.
#
# The following steps happen in modeling_functions.py - Sequence object:
#     4. Create sequences of input tokens of length max_len (used 4, but configurable), followed by the 'labeled' token (or next word).

# %%
# Sequences of length max_len=4 and step=3

max_len = 4
step = 3

# Tokenize
text_train = ProcessText( ads_str_train)
text_test = ProcessText( ads_str_test)

# Print number of tokens
text_train.tokens_info()
text_test.tokens_info()

# Create sequences
seq_train = Sequences(text_train, max_len, step)
seq_train.sequences_info()

# Print number of sequences
seq_test = Sequences(text_test, max_len, step)
seq_test.sequences_info()
# Out:
# tokenizing. Going to preprocess...
# In pre-processing
# tokenizing. Going to preprocess...
# In pre-processing
# total tokens: 289895, distinct tokens: 22567
# total tokens: 31890, distinct tokens: 5637
# number of sequences of length 4: 96631
# number of sequences of length 4: 10629

# %%
len( text_train), len( text_test)
# Out:
# (22567, 5637)

# %%
# Print the first ten tokens and their numeric ids

print(text_train.tokens[:10])
print(text_train.tokens_ind[:10], '\n')

# View 2 sequences 
np.array(seq_train.sequences[:2])
# Out:
# ['Henva', 'Slim', 'Band', 'Compatible', 'with', 'Apple', 'Watch', '38mm', '40mm', '42mm']
# [20837, 319, 15207, 9326, 16658, 12616, 11377, 7113, 1667, 4690]
# array([[20837,   319, 15207,  9326],
#        [ 9326, 16658, 12616, 11377]])

# %% [markdown]
# #### **Interpretation:**
# Each sequence is of length 4, of which 3 are input tokens (X variable) and the 4th is the output (y). This is a self-supervised learning algorithm, and the beauty is that we don't need an extra step of human intervention to label the data!
#
# Tokens and their numeric ids:
# ['ZAGG', 'InvisibleShield', 'Luxe', 'Screen', 'Protector', 'for', 'Apple', 'Watch', 'Series', '2']
# [3393, 963, 9601, 18828, 12556, 10430, 5129, 544, 9532, 9217]
# 3393 is the numeric id for Zagg; 963 is the numeric id for InvisibleShield etc...
#
# Sequence:
# array([[ 3393,   963,  9601, 18828],
#        [18828, 12556, 10430,  5129]])
# Sequence[0] contains: Zagg Invisible Luxe Screen
# Sequence[1] contains Screen Protector for Apple

# %% [markdown]
# #### TextDataGenerator is a subclass of Keras's Sequence superclass used to generate the sequences required during fit.
# TextDataGenerator is called at each step during the model.fit and it returns a batch of sequences containing the X and y variables as defined above.
#
# X is a sparse matrix of shape: batch_size, sequence len, distinct token ids and
# y is of shape: batch_size, distinct token ids

# %%
# Create generator for training data 

params = {
  'sequence_length': max_len,
  'vocab_size': len(text_train),
  'batch_size': batch_size,
  'shuffle': True
}

train_generator = TextDataGenerator(seq_train.sequences, seq_train.next_words, **params)

# %%
# Create generator for testing data 

params_test = {
  'sequence_length': max_len,
  'vocab_size': len(text_test),
  'batch_size': batch_size,
  'shuffle': True
}

test_generator = TextDataGenerator(seq_test.sequences, seq_test.next_words, **params_test)

# %%
len(train_generator), train_generator.batch_size
# Out:
# (23, 4096)

# %%
len(test_generator), test_generator.batch_size
# Out:
# (2, 4096)

# %% [markdown]
# ### Model architecture:
# RNN model with LSTM input layer (with or without Embedding Layer) of 20k nodes (vocabulary size), Dropout to avoid overfitting and output layer using softmax activation.
# <font color="red">The output shape is the size of the vocabulary (20k)</font> which is very different from the 2 in a binary classification or 10 in the MNIST image 0-9 digit classification!

# %%
def lstm_model(sequence_length, vocab_size, layer_size, embedding=False):
  
  # 4, 20k, 128
  print( sequence_length, vocab_size, layer_size)
  
  model = Sequential()
  if embedding:
    model.add(Embedding(vocab_size, layer_size))
    model.add(LSTM(layer_size))    
  else:
    model.add(LSTM(layer_size, input_shape=(sequence_length, vocab_size)))

  ## Second LSTM layer passes outputs forward to next layer
  #model.add(LSTM(layer_size, return_sequences=False))
  #model.add(Dense(layer_size, activation = 'relu', kernel_regularizer=l2(0.001)))

  # Regularization
  model.add(Dropout(0.3))

  model.add(Dense(vocab_size, activation='softmax')) #output shape is equal to vocab size
  return model

# %% [markdown]
# ####
# Create the model and compile with optimizer Adam and metrics applicable for text generation:
# loss='categorical_crossentropy'
# metrics = ['CategoricalAccuracy', 'CategoricalCrossentropy', 'TopKCategoricalAccuracy', 'CategoricalHinge'])
#
# Optionally, use TPU for the model training

# %%
# Set useTPU (in global section at the top) to True to use the TPU. 

if useTPU: 

  tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
  print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])

  tf.config.experimental_connect_to_cluster(tpu)
  tf.tpu.experimental.initialize_tpu_system(tpu)

  strategy = tf.distribute.TPUStrategy(tpu)
  #strategy = tf.distribute.experimental.TPUStrategy(tpu) # experimental is deprecated

  print("REPLICAS: ", strategy.num_replicas_in_sync)

  #
  # Create model with TPU strategy
  #
  with strategy.scope():
    
    print( "Doing create model with TPU")
    model = lstm_model(max_len, len(text_train), layer_size)
    optimizer = tf.keras.optimizers.Adam(learning_rate =0.01)
    #optimizer = tf.keras.optimizers.RMSprop(learning_rate =0.01)

    
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, 
              metrics = ['CategoricalAccuracy', 'CategoricalCrossentropy', 'TopKCategoricalAccuracy', 'CategoricalHinge'])

else: 
    
  print( "Doing create model without TPU")
  model = lstm_model(max_len, len(text_train), layer_size)
  
  # Tried both RMSprop/Adam as optimizer
  optimizer = tf.keras.optimizers.Adam(learning_rate =0.01)
#  optimizer = tf.keras.optimizers.RMSprop(learning_rate =0.01)

  # Metrics applicable for text generation
  model.compile(loss='categorical_crossentropy', optimizer=optimizer, 
              metrics = ['CategoricalAccuracy', 'CategoricalCrossentropy', 'TopKCategoricalAccuracy', 'CategoricalHinge'])
# Out:
# Doing create model without TPU
# 4 22567 128

# %%
model.summary() # 14 million trainable params!
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               11620352
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 22567)             2911143
#
# =================================================================
# Total params: 14,531,495
# Trainable params: 14,531,495
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model.fit
# train_generator is called at each step and it returns a batch of X and y.
# Using the test_generator should work for the validation data, but it gives an error.

# %%
def model_fit( num_epochs):

  history = model.fit(train_generator,
          steps_per_epoch=len(train_generator),
          epochs=num_epochs,
#         validation_data = test_generator, 
          verbose=1)

  return history

# %% [markdown]
# Baseline metrics: No training; 1 epoch

# %%
# get baseline first
baseline_history = model_fit( 1 )
# Out:
# 23/23 [==============================] - 20s 596ms/step - loss: 8.1430 - categorical_accuracy: 0.0513 - categorical_crossentropy: 8.1430 - top_k_categorical_accuracy: 0.1584 - categorical_hinge: 1.0211

# %%
#baseline_history.history

# %%
# train model

history = model_fit( 60)
# Out:
# Epoch 1/60
# 23/23 [==============================] - 14s 582ms/step - loss: 6.8085 - categorical_accuracy: 0.0448 - categorical_crossentropy: 6.8085 - top_k_categorical_accuracy: 0.1598 - categorical_hinge: 1.0390
# Epoch 2/60
# 23/23 [==============================] - 14s 589ms/step - loss: 6.6086 - categorical_accuracy: 0.0543 - categorical_crossentropy: 6.6086 - top_k_categorical_accuracy: 0.1669 - categorical_hinge: 1.0327
# Epoch 3/60
# 23/23 [==============================] - 14s 590ms/step - loss: 6.4341 - categorical_accuracy: 0.0589 - categorical_crossentropy: 6.4341 - top_k_categorical_accuracy: 0.1760 - categorical_hinge: 1.0367
# Epoch 4/60
# 23/23 [==============================] - 15s 629ms/step - loss: 6.1970 - categorical_accuracy: 0.0706 - categorical_crossentropy: 6.1970 - top_k_categorical_accuracy: 0.2056 - categorical_hinge: 1.0419
# Epoch 5/60
# 23/23 [==============================] - 14s 603ms/step - loss: 5.8918 - categorical_accuracy: 0.1073 - categorical_crossentropy: 5.8918 - top_k_categorical_accuracy: 0.2616 - categorical_hinge: 1.0361
# Epoch 6/60
# 23/23 [==============================] - 15s 635ms/step - loss: 5.4705 - categorical_accuracy: 0.1571 - categorical_crossentropy: 5.4705 - top_k_categorical_accuracy: 0.3255 - categorical_hinge: 1.0288
# Epoch 7/60
# 23/23 [==============================] - 14s 608ms/step - loss: 5.0229 - categorical_accuracy: 0.1995 - categorical_crossentropy: 5.0229 - top_k_categorical_accuracy: 0.3790 - categorical_hinge: 1.0190
# Epoch 8/60
# 23/23 [==============================] - 14s 610ms/step - loss: 4.5765 - categorical_accuracy: 0.2389 - categorical_crossentropy: 4.5765 - top_k_categorical_accuracy: 0.4353 - categorical_hinge: 1.0063
# Epoch 9/60
# 23/23 [==============================] - 14s 613ms/step - loss: 4.1154 - categorical_accuracy: 0.2876 - categorical_crossentropy: 4.1154 - top_k_categorical_accuracy: 0.4929 - categorical_hinge: 0.9857
# Epoch 10/60
# 23/23 [==============================] - 15s 641ms/step - loss: 3.6661 - categorical_accuracy: 0.3392 - categorical_crossentropy: 3.6661 - top_k_categorical_accuracy: 0.5546 - categorical_hinge: 0.9606
# Epoch 11/60
# 23/23 [==============================] - 15s 646ms/step - loss: 3.2429 - categorical_accuracy: 0.3937 - categorical_crossentropy: 3.2429 - top_k_categorical_accuracy: 0.6130 - categorical_hinge: 0.9276
# Epoch 12/60
# 23/23 [==============================] - 15s 655ms/step - loss: 2.8649 - categorical_accuracy: 0.4479 - categorical_crossentropy: 2.8649 - top_k_categorical_accuracy: 0.6640 - categorical_hinge: 0.8867
# Epoch 13/60
# 23/23 [==============================] - 15s 639ms/step - loss: 2.5550 - categorical_accuracy: 0.4944 - categorical_crossentropy: 2.5550 - top_k_categorical_accuracy: 0.7073 - categorical_hinge: 0.8438
# Epoch 14/60
# 23/23 [==============================] - 15s 646ms/step - loss: 2.3023 - categorical_accuracy: 0.5313 - categorical_crossentropy: 2.3023 - top_k_categorical_accuracy: 0.7416 - categorical_hinge: 0.8042
# Epoch 15/60
# 23/23 [==============================] - 15s 647ms/step - loss: 2.1032 - categorical_accuracy: 0.5619 - categorical_crossentropy: 2.1032 - top_k_categorical_accuracy: 0.7715 - categorical_hinge: 0.7702
# Epoch 16/60
# 23/23 [==============================] - 15s 628ms/step - loss: 1.9409 - categorical_accuracy: 0.5873 - categorical_crossentropy: 1.9409 - top_k_categorical_accuracy: 0.7927 - categorical_hinge: 0.7407
# Epoch 17/60
# 23/23 [==============================] - 15s 641ms/step - loss: 1.8065 - categorical_accuracy: 0.6108 - categorical_crossentropy: 1.8065 - top_k_categorical_accuracy: 0.8108 - categorical_hinge: 0.7122
# Epoch 18/60
# 23/23 [==============================] - 15s 641ms/step - loss: 1.6910 - categorical_accuracy: 0.6299 - categorical_crossentropy: 1.6910 - top_k_categorical_accuracy: 0.8274 - categorical_hinge: 0.6890
# Epoch 19/60
# 23/23 [==============================] - 15s 629ms/step - loss: 1.5996 - categorical_accuracy: 0.6449 - categorical_crossentropy: 1.5996 - top_k_categorical_accuracy: 0.8387 - categorical_hinge: 0.6677
# Epoch 20/60
# 23/23 [==============================] - 15s 637ms/step - loss: 1.5115 - categorical_accuracy: 0.6593 - categorical_crossentropy: 1.5115 - top_k_categorical_accuracy: 0.8496 - categorical_hinge: 0.6480
# Epoch 21/60
# 23/23 [==============================] - 15s 656ms/step - loss: 1.4477 - categorical_accuracy: 0.6721 - categorical_crossentropy: 1.4477 - top_k_categorical_accuracy: 0.8576 - categorical_hinge: 0.6310
# Epoch 22/60
# 23/23 [==============================] - 15s 644ms/step - loss: 1.3838 - categorical_accuracy: 0.6825 - categorical_crossentropy: 1.3838 - top_k_categorical_accuracy: 0.8654 - categorical_hinge: 0.6152
# Epoch 23/60
# 23/23 [==============================] - 15s 660ms/step - loss: 1.3278 - categorical_accuracy: 0.6910 - categorical_crossentropy: 1.3278 - top_k_categorical_accuracy: 0.8733 - categorical_hinge: 0.6004
# Epoch 24/60
# 23/23 [==============================] - 15s 627ms/step - loss: 1.2706 - categorical_accuracy: 0.7021 - categorical_crossentropy: 1.2706 - top_k_categorical_accuracy: 0.8797 - categorical_hinge: 0.5837
# Epoch 25/60
# 23/23 [==============================] - 15s 660ms/step - loss: 1.2349 - categorical_accuracy: 0.7073 - categorical_crossentropy: 1.2349 - top_k_categorical_accuracy: 0.8855 - categorical_hinge: 0.5741
# Epoch 26/60
# 23/23 [==============================] - 16s 675ms/step - loss: 1.1924 - categorical_accuracy: 0.7161 - categorical_crossentropy: 1.1924 - top_k_categorical_accuracy: 0.8888 - categorical_hinge: 0.5617
# Epoch 27/60
# 23/23 [==============================] - 15s 627ms/step - loss: 1.1578 - categorical_accuracy: 0.7218 - categorical_crossentropy: 1.1578 - top_k_categorical_accuracy: 0.8936 - categorical_hinge: 0.5514
# Epoch 28/60
# 23/23 [==============================] - 15s 631ms/step - loss: 1.1233 - categorical_accuracy: 0.7286 - categorical_crossentropy: 1.1233 - top_k_categorical_accuracy: 0.8982 - categorical_hinge: 0.5421
# Epoch 29/60
# 23/23 [==============================] - 15s 631ms/step - loss: 1.0901 - categorical_accuracy: 0.7356 - categorical_crossentropy: 1.0901 - top_k_categorical_accuracy: 0.9020 - categorical_hinge: 0.5311
# Epoch 30/60
# 23/23 [==============================] - 15s 634ms/step - loss: 1.0543 - categorical_accuracy: 0.7422 - categorical_crossentropy: 1.0543 - top_k_categorical_accuracy: 0.9073 - categorical_hinge: 0.5203
# Epoch 31/60
# 23/23 [==============================] - 15s 632ms/step - loss: 1.0342 - categorical_accuracy: 0.7467 - categorical_crossentropy: 1.0342 - top_k_categorical_accuracy: 0.9082 - categorical_hinge: 0.5135
# Epoch 32/60
# 23/23 [==============================] - 15s 651ms/step - loss: 1.0058 - categorical_accuracy: 0.7498 - categorical_crossentropy: 1.0058 - top_k_categorical_accuracy: 0.9127 - categorical_hinge: 0.5055
# Epoch 33/60
# 23/23 [==============================] - 15s 643ms/step - loss: 0.9909 - categorical_accuracy: 0.7545 - categorical_crossentropy: 0.9909 - top_k_categorical_accuracy: 0.9141 - categorical_hinge: 0.4999
# Epoch 34/60
# 23/23 [==============================] - 15s 631ms/step - loss: 0.9641 - categorical_accuracy: 0.7609 - categorical_crossentropy: 0.9641 - top_k_categorical_accuracy: 0.9164 - categorical_hinge: 0.4903
# Epoch 35/60
# 23/23 [==============================] - 15s 665ms/step - loss: 0.9385 - categorical_accuracy: 0.7646 - categorical_crossentropy: 0.9385 - top_k_categorical_accuracy: 0.9204 - categorical_hinge: 0.4831
# Epoch 36/60
# 23/23 [==============================] - 15s 654ms/step - loss: 0.9205 - categorical_accuracy: 0.7677 - categorical_crossentropy: 0.9205 - top_k_categorical_accuracy: 0.9224 - categorical_hinge: 0.4768
# Epoch 37/60
# 23/23 [==============================] - 15s 643ms/step - loss: 0.8963 - categorical_accuracy: 0.7729 - categorical_crossentropy: 0.8963 - top_k_categorical_accuracy: 0.9263 - categorical_hinge: 0.4682
# Epoch 38/60
# 23/23 [==============================] - 15s 629ms/step - loss: 0.8863 - categorical_accuracy: 0.7738 - categorical_crossentropy: 0.8863 - top_k_categorical_accuracy: 0.9268 - categorical_hinge: 0.4659
# Epoch 39/60
# 23/23 [==============================] - 15s 633ms/step - loss: 0.8684 - categorical_accuracy: 0.7774 - categorical_crossentropy: 0.8684 - top_k_categorical_accuracy: 0.9295 - categorical_hinge: 0.4600
# Epoch 40/60
# 23/23 [==============================] - 15s 630ms/step - loss: 0.8517 - categorical_accuracy: 0.7813 - categorical_crossentropy: 0.8517 - top_k_categorical_accuracy: 0.9307 - categorical_hinge: 0.4533
# Epoch 41/60
# 23/23 [==============================] - 15s 632ms/step - loss: 0.8406 - categorical_accuracy: 0.7831 - categorical_crossentropy: 0.8406 - top_k_categorical_accuracy: 0.9316 - categorical_hinge: 0.4484
# Epoch 42/60
# 23/23 [==============================] - 15s 633ms/step - loss: 0.8248 - categorical_accuracy: 0.7869 - categorical_crossentropy: 0.8248 - top_k_categorical_accuracy: 0.9337 - categorical_hinge: 0.4430
# Epoch 43/60
# 23/23 [==============================] - 15s 635ms/step - loss: 0.8096 - categorical_accuracy: 0.7896 - categorical_crossentropy: 0.8096 - top_k_categorical_accuracy: 0.9354 - categorical_hinge: 0.4385
# Epoch 44/60
# 23/23 [==============================] - 15s 634ms/step - loss: 0.7984 - categorical_accuracy: 0.7919 - categorical_crossentropy: 0.7984 - top_k_categorical_accuracy: 0.9372 - categorical_hinge: 0.4336
# Epoch 45/60
# 23/23 [==============================] - 15s 667ms/step - loss: 0.7847 - categorical_accuracy: 0.7946 - categorical_crossentropy: 0.7847 - top_k_categorical_accuracy: 0.9397 - categorical_hinge: 0.4295
# Epoch 46/60
# 23/23 [==============================] - 15s 634ms/step - loss: 0.7689 - categorical_accuracy: 0.7977 - categorical_crossentropy: 0.7689 - top_k_categorical_accuracy: 0.9403 - categorical_hinge: 0.4233
# Epoch 47/60
# 23/23 [==============================] - 16s 677ms/step - loss: 0.7590 - categorical_accuracy: 0.7992 - categorical_crossentropy: 0.7590 - top_k_categorical_accuracy: 0.9415 - categorical_hinge: 0.4192
# Epoch 48/60
# 23/23 [==============================] - 15s 648ms/step - loss: 0.7493 - categorical_accuracy: 0.8016 - categorical_crossentropy: 0.7493 - top_k_categorical_accuracy: 0.9428 - categorical_hinge: 0.4154
# Epoch 49/60
# 23/23 [==============================] - 15s 634ms/step - loss: 0.7397 - categorical_accuracy: 0.8046 - categorical_crossentropy: 0.7397 - top_k_categorical_accuracy: 0.9439 - categorical_hinge: 0.4115
# Epoch 50/60
# 23/23 [==============================] - 15s 635ms/step - loss: 0.7316 - categorical_accuracy: 0.8046 - categorical_crossentropy: 0.7316 - top_k_categorical_accuracy: 0.9454 - categorical_hinge: 0.4090
# Epoch 51/60
# 23/23 [==============================] - 15s 638ms/step - loss: 0.7238 - categorical_accuracy: 0.8067 - categorical_crossentropy: 0.7238 - top_k_categorical_accuracy: 0.9458 - categorical_hinge: 0.4060
# Epoch 52/60
# 23/23 [==============================] - 15s 638ms/step - loss: 0.7120 - categorical_accuracy: 0.8087 - categorical_crossentropy: 0.7120 - top_k_categorical_accuracy: 0.9471 - categorical_hinge: 0.4017
# Epoch 53/60
# 23/23 [==============================] - 15s 639ms/step - loss: 0.7078 - categorical_accuracy: 0.8104 - categorical_crossentropy: 0.7078 - top_k_categorical_accuracy: 0.9478 - categorical_hinge: 0.3999
# Epoch 54/60
# 23/23 [==============================] - 15s 661ms/step - loss: 0.6963 - categorical_accuracy: 0.8123 - categorical_crossentropy: 0.6963 - top_k_categorical_accuracy: 0.9492 - categorical_hinge: 0.3959
# Epoch 55/60
# 23/23 [==============================] - 15s 638ms/step - loss: 0.6872 - categorical_accuracy: 0.8148 - categorical_crossentropy: 0.6872 - top_k_categorical_accuracy: 0.9502 - categorical_hinge: 0.3913
# Epoch 56/60
# 23/23 [==============================] - 15s 661ms/step - loss: 0.6761 - categorical_accuracy: 0.8178 - categorical_crossentropy: 0.6761 - top_k_categorical_accuracy: 0.9514 - categorical_hinge: 0.3868
# Epoch 57/60
# 23/23 [==============================] - 15s 642ms/step - loss: 0.6726 - categorical_accuracy: 0.8180 - categorical_crossentropy: 0.6726 - top_k_categorical_accuracy: 0.9521 - categorical_hinge: 0.3856
# Epoch 58/60
# 23/23 [==============================] - 15s 639ms/step - loss: 0.6658 - categorical_accuracy: 0.8191 - categorical_crossentropy: 0.6658 - top_k_categorical_accuracy: 0.9523 - categorical_hinge: 0.3823
# Epoch 59/60
# 23/23 [==============================] - 15s 633ms/step - loss: 0.6563 - categorical_accuracy: 0.8211 - categorical_crossentropy: 0.6563 - top_k_categorical_accuracy: 0.9537 - categorical_hinge: 0.3784
# Epoch 60/60
# 23/23 [==============================] - 15s 635ms/step - loss: 0.6499 - categorical_accuracy: 0.8230 - categorical_crossentropy: 0.6499 - top_k_categorical_accuracy: 0.9537 - categorical_hinge: 0.3753

# %%
# Save the model for inference purposes
model.save('../data/lstm_model_13krows_batch4k.h5')

# %% [markdown]
# ### Modeling done!
# Evaluate the model performance with graphs and metrics vs baseline

# %%
# Plot loss and accuracy metrics 

def plot_metrics(history, title):
  fig, (ax1, ax2, ax3, ax4) = plt.subplots(1,4, figsize = (14,6))

  ## Plot Training & Validation Loss
  ax1.plot(history.history['loss'], label="Loss")
  #ax1.plot(history.history['loss'], label="Training Loss")
  #ax1.plot(history.history['val_loss'], label="Testing Loss")
  ax1.legend();

  ## Plot Training & Validation Accuracy
  ax2.plot(history.history['categorical_accuracy'], label="Categorical Accuracy")
  #ax2.plot(history.history['categorical_accuracy'], label="Training Cat Accuracy")
  #ax2.plot(history.history['val_accuracy'], label="Testing Accuracy")
  ax2.legend();

  ax3.plot(history.history['top_k_categorical_accuracy'], label="Top K Categorical Accuracy")
  #ax3.plot(history.history['top_k_categorical_accuracy'], label="Training TopKCatAccuracy")
  ax3.legend();

  ax4.plot(history.history['categorical_hinge'], label="Categorical_hinge")
  #ax4.plot(history.history['categorical_hinge'], label="Training categorical_hinge")
  ax4.legend();

  plt.suptitle(title);

# %%
plot_metrics(baseline_history, "Evaluation of baseline (untrained) RNN LSTM model")
# only 1 epoch so no history for graph

# %%
plot_metrics(history, "Evaluation of RNN LSTM model")

# %% [markdown]
# #### **Interpretation:**
# The graphs are trending in the right direction - the loss is decreasing as the epochs increase and the categorical and TopK Categorical Accuracies are increasing.
# They are plateauing as the epochs increase, but maybe with more epochs they could be better.
# Validation data was giving an error so I couldn't plot the validation loss and accuracy which would have helped check for overfitting.

# %%
#model.score()
#train_generator.vocab_size
df_ads_train.shape, df_ads.shape
# Out:
# ((11592, 3), (12880, 3))

# %% [markdown]
# #### Compute model evaluation metrics

# %%
def evaluate_model(baseline_history, history):

  results_df = pd.DataFrame()

  results_df["max_rows"] = [max_rows]
  results_df["Actual Rows"] = [df_ads_train.shape]
  results_df["batch_size"] = [train_generator.batch_size]

  total_tokens, distinct_tokens = text_train.tokens_info()
  #print( total_tokens, distinct_tokens)

  results_df["total_tokens"] = [total_tokens]
  results_df["distinct_tokens"] = [distinct_tokens]
  results_df["steps_per_epoch"] = [len(train_generator)]

  results_df["Baseline Categorical Accuracy"] = max(baseline_history.history['categorical_accuracy'])
  results_df["Categorical Accuracy"] = max(history.history['categorical_accuracy'])

  results_df["Baseline Categorical Crossentropy"] = min(baseline_history.history['categorical_crossentropy']) #Loss
  results_df["Categorical Crossentropy"] = min(history.history['categorical_crossentropy']) #Loss
  
  results_df["Baseline Top K Categorical Accuracy"] = max(baseline_history.history['top_k_categorical_accuracy'])
  results_df["Top K Categorical Accuracy"] = max(history.history['top_k_categorical_accuracy'])

  return results_df

# %% [markdown]
# #### Write metrics to file

# %%
results_df = evaluate_model(baseline_history,  history)

results_df["Model"]= ["LSTM"]*len(results_df)

# save the metric results to file
results_df.to_csv("../data/lstm_results_df_holidays.csv")
# Out:
# total tokens: 289895, distinct tokens: 22567

# %%
results_df
# Out:
#    max_rows Actual Rows  batch_size  total_tokens  distinct_tokens  \
# 0     15000  (11592, 3)        4096        289895            22567
#
#    steps_per_epoch  Baseline Categorical Accuracy  Categorical Accuracy  \
# 0               23                       0.051323              0.822998
#
#    Baseline Categorical Crossentropy  Categorical Crossentropy  \
# 0                           8.143008                  0.649934
#
#    Baseline Top K Categorical Accuracy  Top K Categorical Accuracy Model
# 0                             0.158394                    0.953698  LSTM

# %% [markdown]
# #### **Interpretation:**
#
# Much better than baseline.

# %% [markdown]
# ### Now comes the fun part! Inference.
# Let's generate some text and see what results we get.

# %%
# Specify the input prompt. This can be a few words with keywords for the ad. 
# Examples are: Last minute Memorial Day deals on Samsung headphones' or the others commented out below. 

input_prefix = 'Last minute Memorial Day deals on Samsung headphones'
#input_prefix = 'Apple watch'
#input_prefix = 'Mothers Day savings on'
#input_prefix = 'Big savings on the new'

#input_prefix = 'Sony TV'
#input_prefix = 'Sony PS3'
#input_prefix = 'Sony Playstation' 

token2ind, ind2token = text_train.token2ind, text_train.ind2token
text_prefix = ProcessText(input_prefix, token2ind, ind2token)
# Out:
# tokenizing. Going to preprocess...
# In pre-processing

# %% [markdown]
# #### First instantiate an instance of the class ModelPredict (defined in modeling_functions.py), passing in the input prompt and the trained model.

# %%
pred = ModelPredict(model, text_prefix, token2ind, ind2token, max_len)

# %% [markdown]
# ### Let's see the generated text for different temperatures.
#
# Temperature controls the randomness of the generated text. A value of 0 makes the engine deterministic, which means that it will always generate the same output for a given input text. A value of 1 makes the engine take the most risks and use a lot of creativity.
#
# #### Temperature sampling is inspired by statistical thermodynamics, where high temperature means low energy states are more likely encountered.
# In probability models, logits play the role of energy and we can implement temperature sampling by dividing logits by the temperature before feeding them into softmax and obtaining our sampling probabilities.

# %%
#### generate_sequence calls the trained models's .predict function after converting the input words to their numeric ids 
# and vice versa after the models prediction. It also handles temperature. 

temperatures = [1, 0.7, 0.4, 0.1]

for temperature in temperatures:
  print('temperature:', temperature)
  print(pred.generate_sequence(30, temperature=temperature))
  print('\n')
# Out:
# temperature: 1
# Last minute Memorial Day deals on Samsung headphones by, VR, Black, HD Clear Portable HD Digital TV Antenna, SOONHUA, for Garmin Vivofit 3, Paw 4000, LT TV Antenna, DVD,
#
#
# temperature: 0.7
# Last minute Memorial Day deals on Samsung headphones by Games, 3D VR Headset for iPhone & Android Phones- 6. 8G 40CH FPV Inch inch. 5- 24 inch Maximum LCD Displays, Adjustable Replacement
#
#
# temperature: 0.4
# Last minute Memorial Day deals on Samsung headphones by, VR, 3D VR Movies,, Games Extreme WIFI 5000 BDA103HB Full Wireless Outdoor Audio Projector, Support for Home Theater, Game and Gaming Video to
#
#
# temperature: 0.1
# Last minute Memorial Day deals on Samsung headphones by, VR, 3D VR Movies, Compatible with Apple Watch Band 38mm 40mm 42mm 44mm, Soft Silicone Sport Strap Replacement Wristband for Samsung Galaxy Watch Active 40mm

# %% [markdown]
# #### **Interpretation:**
# At lower temperature, there may be repitition of words. Typically, results are best with temperature 0.7.
#
# The ad text generated is decent!
# In fact, given that our training data size is not large, the results are a lot better than I had expected.
#
# However, other Generative Pre-trained Transformer models like OpenAI's GPT-3 and Eleuther's GPT-NEO are trained on 800+GB of data and do a really good job of generating text.
#
# We will compare our model's output with these models after the Embedding section below.

# %% [markdown]
# ### LSTM with Embedding layer

# %% [markdown]
# #### Now try with Embedding Layer

# %%
batch_size_emb = batch_size

params_emb = params.copy()
params_emb['embedding'] = True

train_generator_emb = TextDataGenerator(seq_train.sequences, seq_train.next_words, **params_emb)

# %%
# Tried 128, 64 and 16 as vector dimensions, 128 is best. 
 
model_emb = lstm_model(max_len, len(text_train), layer_size, embedding=True)
#model_emb = lstm_model(max_len, len(text_train), 128, embedding=True)

model_emb.compile(loss='categorical_crossentropy', optimizer=optimizer, 
              metrics = ['CategoricalAccuracy', 'CategoricalCrossentropy', 'TopKCategoricalAccuracy', 'CategoricalHinge'])
# Out:
# 4 22567 128

# %%
model_emb.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 128)         2888576
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 22567)             2911143
#
# =================================================================
# Total params: 5,931,303
# Trainable params: 5,931,303
# Non-trainable params: 0
# _________________________________________________________________

# %%
def emb_model_fit( num_epochs):
  history_emb = model_emb.fit(train_generator_emb,
              steps_per_epoch=len(train_generator_emb),
              epochs=num_epochs,
              verbose=1)
  return history_emb

# %%
# get baseline first with just 1 epoch (no training)
emb_baseline_history = emb_model_fit( 1 )
# Out:
# 23/23 [==============================] - 8s 265ms/step - loss: 8.7714 - categorical_accuracy: 0.0434 - categorical_crossentropy: 8.7714 - top_k_categorical_accuracy: 0.1256 - categorical_hinge: 1.0456

# %%
emb_history = emb_model_fit( 100 )
# Out:
# Epoch 1/100
# 23/23 [==============================] - 6s 270ms/step - loss: 6.8022 - categorical_accuracy: 0.0677 - categorical_crossentropy: 6.8022 - top_k_categorical_accuracy: 0.1814 - categorical_hinge: 1.0473
# Epoch 2/100
# 23/23 [==============================] - 6s 268ms/step - loss: 6.0319 - categorical_accuracy: 0.1168 - categorical_crossentropy: 6.0319 - top_k_categorical_accuracy: 0.2582 - categorical_hinge: 1.0358
# Epoch 3/100
# 23/23 [==============================] - 6s 263ms/step - loss: 5.5295 - categorical_accuracy: 0.1526 - categorical_crossentropy: 5.5295 - top_k_categorical_accuracy: 0.3151 - categorical_hinge: 1.0268
# Epoch 4/100
# 23/23 [==============================] - 8s 334ms/step - loss: 5.1471 - categorical_accuracy: 0.1803 - categorical_crossentropy: 5.1471 - top_k_categorical_accuracy: 0.3534 - categorical_hinge: 1.0218
# Epoch 5/100
# 23/23 [==============================] - 6s 266ms/step - loss: 4.8277 - categorical_accuracy: 0.2044 - categorical_crossentropy: 4.8277 - top_k_categorical_accuracy: 0.3858 - categorical_hinge: 1.0155
# Epoch 6/100
# 23/23 [==============================] - 6s 264ms/step - loss: 4.5433 - categorical_accuracy: 0.2271 - categorical_crossentropy: 4.5433 - top_k_categorical_accuracy: 0.4169 - categorical_hinge: 1.0092
# Epoch 7/100
# 23/23 [==============================] - 6s 265ms/step - loss: 4.2967 - categorical_accuracy: 0.2491 - categorical_crossentropy: 4.2967 - top_k_categorical_accuracy: 0.4466 - categorical_hinge: 1.0017
# Epoch 8/100
# 23/23 [==============================] - 6s 264ms/step - loss: 4.0685 - categorical_accuracy: 0.2701 - categorical_crossentropy: 4.0685 - top_k_categorical_accuracy: 0.4787 - categorical_hinge: 0.9938
# Epoch 9/100
# 23/23 [==============================] - 6s 265ms/step - loss: 3.8629 - categorical_accuracy: 0.2924 - categorical_crossentropy: 3.8629 - top_k_categorical_accuracy: 0.5072 - categorical_hinge: 0.9839
# Epoch 10/100
# 23/23 [==============================] - 6s 265ms/step - loss: 3.6855 - categorical_accuracy: 0.3148 - categorical_crossentropy: 3.6855 - top_k_categorical_accuracy: 0.5320 - categorical_hinge: 0.9746
# Epoch 11/100
# 23/23 [==============================] - 6s 266ms/step - loss: 3.5277 - categorical_accuracy: 0.3333 - categorical_crossentropy: 3.5277 - top_k_categorical_accuracy: 0.5534 - categorical_hinge: 0.9648
# Epoch 12/100
# 23/23 [==============================] - 6s 267ms/step - loss: 3.3838 - categorical_accuracy: 0.3517 - categorical_crossentropy: 3.3838 - top_k_categorical_accuracy: 0.5753 - categorical_hinge: 0.9528
# Epoch 13/100
# 23/23 [==============================] - 6s 266ms/step - loss: 3.2566 - categorical_accuracy: 0.3696 - categorical_crossentropy: 3.2566 - top_k_categorical_accuracy: 0.5939 - categorical_hinge: 0.9422
# Epoch 14/100
# 23/23 [==============================] - 6s 269ms/step - loss: 3.1500 - categorical_accuracy: 0.3826 - categorical_crossentropy: 3.1500 - top_k_categorical_accuracy: 0.6072 - categorical_hinge: 0.9322
# Epoch 15/100
# 23/23 [==============================] - 6s 267ms/step - loss: 3.0473 - categorical_accuracy: 0.3950 - categorical_crossentropy: 3.0473 - top_k_categorical_accuracy: 0.6204 - categorical_hinge: 0.9212
# Epoch 16/100
# 23/23 [==============================] - 6s 268ms/step - loss: 2.9503 - categorical_accuracy: 0.4099 - categorical_crossentropy: 2.9503 - top_k_categorical_accuracy: 0.6351 - categorical_hinge: 0.9108
# Epoch 17/100
# 23/23 [==============================] - 6s 267ms/step - loss: 2.8682 - categorical_accuracy: 0.4194 - categorical_crossentropy: 2.8682 - top_k_categorical_accuracy: 0.6489 - categorical_hinge: 0.9024
# Epoch 18/100
# 23/23 [==============================] - 6s 269ms/step - loss: 2.7923 - categorical_accuracy: 0.4310 - categorical_crossentropy: 2.7923 - top_k_categorical_accuracy: 0.6570 - categorical_hinge: 0.8923
# Epoch 19/100
# 23/23 [==============================] - 6s 267ms/step - loss: 2.7218 - categorical_accuracy: 0.4413 - categorical_crossentropy: 2.7218 - top_k_categorical_accuracy: 0.6684 - categorical_hinge: 0.8829
# Epoch 20/100
# 23/23 [==============================] - 6s 269ms/step - loss: 2.6595 - categorical_accuracy: 0.4485 - categorical_crossentropy: 2.6595 - top_k_categorical_accuracy: 0.6758 - categorical_hinge: 0.8747
# Epoch 21/100
# 23/23 [==============================] - 6s 269ms/step - loss: 2.6015 - categorical_accuracy: 0.4589 - categorical_crossentropy: 2.6015 - top_k_categorical_accuracy: 0.6856 - categorical_hinge: 0.8676
# Epoch 22/100
# 23/23 [==============================] - 6s 268ms/step - loss: 2.5433 - categorical_accuracy: 0.4683 - categorical_crossentropy: 2.5433 - top_k_categorical_accuracy: 0.6937 - categorical_hinge: 0.8587
# Epoch 23/100
# 23/23 [==============================] - 6s 269ms/step - loss: 2.4921 - categorical_accuracy: 0.4761 - categorical_crossentropy: 2.4921 - top_k_categorical_accuracy: 0.7016 - categorical_hinge: 0.8516
# Epoch 24/100
# 23/23 [==============================] - 6s 268ms/step - loss: 2.4475 - categorical_accuracy: 0.4821 - categorical_crossentropy: 2.4475 - top_k_categorical_accuracy: 0.7077 - categorical_hinge: 0.8448
# Epoch 25/100
# 23/23 [==============================] - 6s 268ms/step - loss: 2.4037 - categorical_accuracy: 0.4910 - categorical_crossentropy: 2.4037 - top_k_categorical_accuracy: 0.7130 - categorical_hinge: 0.8369
# Epoch 26/100
# 23/23 [==============================] - 6s 266ms/step - loss: 2.3562 - categorical_accuracy: 0.4962 - categorical_crossentropy: 2.3562 - top_k_categorical_accuracy: 0.7217 - categorical_hinge: 0.8303
# Epoch 27/100
# 23/23 [==============================] - 6s 268ms/step - loss: 2.3197 - categorical_accuracy: 0.5024 - categorical_crossentropy: 2.3197 - top_k_categorical_accuracy: 0.7253 - categorical_hinge: 0.8236
# Epoch 28/100
# 23/23 [==============================] - 6s 269ms/step - loss: 2.2824 - categorical_accuracy: 0.5084 - categorical_crossentropy: 2.2824 - top_k_categorical_accuracy: 0.7312 - categorical_hinge: 0.8185
# Epoch 29/100
# 23/23 [==============================] - 6s 269ms/step - loss: 2.2419 - categorical_accuracy: 0.5158 - categorical_crossentropy: 2.2419 - top_k_categorical_accuracy: 0.7373 - categorical_hinge: 0.8112
# Epoch 30/100
# 23/23 [==============================] - 6s 269ms/step - loss: 2.2053 - categorical_accuracy: 0.5216 - categorical_crossentropy: 2.2053 - top_k_categorical_accuracy: 0.7423 - categorical_hinge: 0.8048
# Epoch 31/100
# 23/23 [==============================] - 6s 268ms/step - loss: 2.1762 - categorical_accuracy: 0.5258 - categorical_crossentropy: 2.1762 - top_k_categorical_accuracy: 0.7463 - categorical_hinge: 0.7990
# Epoch 32/100
# 23/23 [==============================] - 6s 269ms/step - loss: 2.1441 - categorical_accuracy: 0.5319 - categorical_crossentropy: 2.1441 - top_k_categorical_accuracy: 0.7508 - categorical_hinge: 0.7935
# Epoch 33/100
# 23/23 [==============================] - 6s 269ms/step - loss: 2.1201 - categorical_accuracy: 0.5331 - categorical_crossentropy: 2.1201 - top_k_categorical_accuracy: 0.7532 - categorical_hinge: 0.7897
# Epoch 34/100
# 23/23 [==============================] - 6s 268ms/step - loss: 2.0935 - categorical_accuracy: 0.5392 - categorical_crossentropy: 2.0935 - top_k_categorical_accuracy: 0.7593 - categorical_hinge: 0.7851
# Epoch 35/100
# 23/23 [==============================] - 6s 268ms/step - loss: 2.0587 - categorical_accuracy: 0.5437 - categorical_crossentropy: 2.0587 - top_k_categorical_accuracy: 0.7636 - categorical_hinge: 0.7779
# Epoch 36/100
# 23/23 [==============================] - 6s 268ms/step - loss: 2.0353 - categorical_accuracy: 0.5488 - categorical_crossentropy: 2.0353 - top_k_categorical_accuracy: 0.7662 - categorical_hinge: 0.7719
# Epoch 37/100
# 23/23 [==============================] - 6s 267ms/step - loss: 2.0102 - categorical_accuracy: 0.5540 - categorical_crossentropy: 2.0102 - top_k_categorical_accuracy: 0.7706 - categorical_hinge: 0.7681
# Epoch 38/100
# 23/23 [==============================] - 6s 268ms/step - loss: 1.9818 - categorical_accuracy: 0.5590 - categorical_crossentropy: 1.9818 - top_k_categorical_accuracy: 0.7734 - categorical_hinge: 0.7616
# Epoch 39/100
# 23/23 [==============================] - 6s 269ms/step - loss: 1.9667 - categorical_accuracy: 0.5592 - categorical_crossentropy: 1.9667 - top_k_categorical_accuracy: 0.7765 - categorical_hinge: 0.7598
# Epoch 40/100
# 23/23 [==============================] - 6s 270ms/step - loss: 1.9393 - categorical_accuracy: 0.5642 - categorical_crossentropy: 1.9393 - top_k_categorical_accuracy: 0.7800 - categorical_hinge: 0.7550
# Epoch 41/100
# 23/23 [==============================] - 6s 269ms/step - loss: 1.9200 - categorical_accuracy: 0.5681 - categorical_crossentropy: 1.9200 - top_k_categorical_accuracy: 0.7822 - categorical_hinge: 0.7495
# Epoch 42/100
# 23/23 [==============================] - 6s 272ms/step - loss: 1.9030 - categorical_accuracy: 0.5709 - categorical_crossentropy: 1.9030 - top_k_categorical_accuracy: 0.7855 - categorical_hinge: 0.7463
# Epoch 43/100
# 23/23 [==============================] - 6s 268ms/step - loss: 1.8801 - categorical_accuracy: 0.5750 - categorical_crossentropy: 1.8801 - top_k_categorical_accuracy: 0.7889 - categorical_hinge: 0.7415
# Epoch 44/100
# 23/23 [==============================] - 6s 268ms/step - loss: 1.8629 - categorical_accuracy: 0.5770 - categorical_crossentropy: 1.8629 - top_k_categorical_accuracy: 0.7910 - categorical_hinge: 0.7391
# Epoch 45/100
# 23/23 [==============================] - 6s 270ms/step - loss: 1.8480 - categorical_accuracy: 0.5793 - categorical_crossentropy: 1.8480 - top_k_categorical_accuracy: 0.7930 - categorical_hinge: 0.7347
# Epoch 46/100
# 23/23 [==============================] - 6s 271ms/step - loss: 1.8331 - categorical_accuracy: 0.5838 - categorical_crossentropy: 1.8331 - top_k_categorical_accuracy: 0.7950 - categorical_hinge: 0.7305
# Epoch 47/100
# 23/23 [==============================] - 6s 268ms/step - loss: 1.8182 - categorical_accuracy: 0.5856 - categorical_crossentropy: 1.8182 - top_k_categorical_accuracy: 0.7961 - categorical_hinge: 0.7275
# Epoch 48/100
# 23/23 [==============================] - 6s 267ms/step - loss: 1.8017 - categorical_accuracy: 0.5894 - categorical_crossentropy: 1.8017 - top_k_categorical_accuracy: 0.8003 - categorical_hinge: 0.7256
# Epoch 49/100
# 23/23 [==============================] - 6s 269ms/step - loss: 1.7827 - categorical_accuracy: 0.5925 - categorical_crossentropy: 1.7827 - top_k_categorical_accuracy: 0.8018 - categorical_hinge: 0.7195
# Epoch 50/100
# 23/23 [==============================] - 6s 270ms/step - loss: 1.7661 - categorical_accuracy: 0.5939 - categorical_crossentropy: 1.7661 - top_k_categorical_accuracy: 0.8043 - categorical_hinge: 0.7177
# Epoch 51/100
# 23/23 [==============================] - 6s 270ms/step - loss: 1.7500 - categorical_accuracy: 0.5976 - categorical_crossentropy: 1.7500 - top_k_categorical_accuracy: 0.8061 - categorical_hinge: 0.7128
# Epoch 52/100
# 23/23 [==============================] - 6s 270ms/step - loss: 1.7379 - categorical_accuracy: 0.6004 - categorical_crossentropy: 1.7379 - top_k_categorical_accuracy: 0.8085 - categorical_hinge: 0.7105
# Epoch 53/100
# 23/23 [==============================] - 6s 271ms/step - loss: 1.7240 - categorical_accuracy: 0.6020 - categorical_crossentropy: 1.7240 - top_k_categorical_accuracy: 0.8103 - categorical_hinge: 0.7081
# Epoch 54/100
# 23/23 [==============================] - 6s 269ms/step - loss: 1.7092 - categorical_accuracy: 0.6034 - categorical_crossentropy: 1.7092 - top_k_categorical_accuracy: 0.8120 - categorical_hinge: 0.7042
# Epoch 55/100
# 23/23 [==============================] - 6s 267ms/step - loss: 1.6957 - categorical_accuracy: 0.6065 - categorical_crossentropy: 1.6957 - top_k_categorical_accuracy: 0.8147 - categorical_hinge: 0.7021
# Epoch 56/100
# 23/23 [==============================] - 6s 272ms/step - loss: 1.6862 - categorical_accuracy: 0.6086 - categorical_crossentropy: 1.6862 - top_k_categorical_accuracy: 0.8163 - categorical_hinge: 0.6992
# Epoch 57/100
# 23/23 [==============================] - 6s 267ms/step - loss: 1.6746 - categorical_accuracy: 0.6117 - categorical_crossentropy: 1.6746 - top_k_categorical_accuracy: 0.8166 - categorical_hinge: 0.6958
# Epoch 58/100
# 23/23 [==============================] - 6s 271ms/step - loss: 1.6598 - categorical_accuracy: 0.6130 - categorical_crossentropy: 1.6598 - top_k_categorical_accuracy: 0.8192 - categorical_hinge: 0.6924
# Epoch 59/100
# 23/23 [==============================] - 6s 273ms/step - loss: 1.6498 - categorical_accuracy: 0.6154 - categorical_crossentropy: 1.6498 - top_k_categorical_accuracy: 0.8198 - categorical_hinge: 0.6904
# Epoch 60/100
# 23/23 [==============================] - 6s 271ms/step - loss: 1.6425 - categorical_accuracy: 0.6170 - categorical_crossentropy: 1.6425 - top_k_categorical_accuracy: 0.8222 - categorical_hinge: 0.6876
# Epoch 61/100
# 23/23 [==============================] - 6s 272ms/step - loss: 1.6330 - categorical_accuracy: 0.6192 - categorical_crossentropy: 1.6330 - top_k_categorical_accuracy: 0.8220 - categorical_hinge: 0.6858
# Epoch 62/100
# 23/23 [==============================] - 6s 271ms/step - loss: 1.6180 - categorical_accuracy: 0.6222 - categorical_crossentropy: 1.6180 - top_k_categorical_accuracy: 0.8254 - categorical_hinge: 0.6815
# Epoch 63/100
# 23/23 [==============================] - 6s 271ms/step - loss: 1.6111 - categorical_accuracy: 0.6232 - categorical_crossentropy: 1.6111 - top_k_categorical_accuracy: 0.8254 - categorical_hinge: 0.6801
# Epoch 64/100
# 23/23 [==============================] - 6s 275ms/step - loss: 1.5966 - categorical_accuracy: 0.6251 - categorical_crossentropy: 1.5966 - top_k_categorical_accuracy: 0.8281 - categorical_hinge: 0.6773
# Epoch 65/100
# 23/23 [==============================] - 6s 275ms/step - loss: 1.5897 - categorical_accuracy: 0.6261 - categorical_crossentropy: 1.5897 - top_k_categorical_accuracy: 0.8285 - categorical_hinge: 0.6750
# Epoch 66/100
# 23/23 [==============================] - 7s 275ms/step - loss: 1.5757 - categorical_accuracy: 0.6282 - categorical_crossentropy: 1.5757 - top_k_categorical_accuracy: 0.8299 - categorical_hinge: 0.6717
# Epoch 67/100
# 23/23 [==============================] - 7s 276ms/step - loss: 1.5671 - categorical_accuracy: 0.6310 - categorical_crossentropy: 1.5671 - top_k_categorical_accuracy: 0.8322 - categorical_hinge: 0.6709
# Epoch 68/100
# 23/23 [==============================] - 6s 274ms/step - loss: 1.5640 - categorical_accuracy: 0.6303 - categorical_crossentropy: 1.5640 - top_k_categorical_accuracy: 0.8328 - categorical_hinge: 0.6692
# Epoch 69/100
# 23/23 [==============================] - 7s 277ms/step - loss: 1.5530 - categorical_accuracy: 0.6338 - categorical_crossentropy: 1.5530 - top_k_categorical_accuracy: 0.8331 - categorical_hinge: 0.6655
# Epoch 70/100
# 23/23 [==============================] - 6s 274ms/step - loss: 1.5397 - categorical_accuracy: 0.6351 - categorical_crossentropy: 1.5397 - top_k_categorical_accuracy: 0.8355 - categorical_hinge: 0.6630
# Epoch 71/100
# 23/23 [==============================] - 7s 276ms/step - loss: 1.5371 - categorical_accuracy: 0.6361 - categorical_crossentropy: 1.5371 - top_k_categorical_accuracy: 0.8354 - categorical_hinge: 0.6632
# Epoch 72/100
# 23/23 [==============================] - 7s 275ms/step - loss: 1.5252 - categorical_accuracy: 0.6374 - categorical_crossentropy: 1.5252 - top_k_categorical_accuracy: 0.8374 - categorical_hinge: 0.6599
# Epoch 73/100
# 23/23 [==============================] - 7s 276ms/step - loss: 1.5174 - categorical_accuracy: 0.6397 - categorical_crossentropy: 1.5174 - top_k_categorical_accuracy: 0.8381 - categorical_hinge: 0.6580
# Epoch 74/100
# 23/23 [==============================] - 6s 276ms/step - loss: 1.5094 - categorical_accuracy: 0.6423 - categorical_crossentropy: 1.5094 - top_k_categorical_accuracy: 0.8394 - categorical_hinge: 0.6550
# Epoch 75/100
# 23/23 [==============================] - 7s 277ms/step - loss: 1.5041 - categorical_accuracy: 0.6418 - categorical_crossentropy: 1.5041 - top_k_categorical_accuracy: 0.8404 - categorical_hinge: 0.6543
# Epoch 76/100
# 23/23 [==============================] - 6s 276ms/step - loss: 1.4975 - categorical_accuracy: 0.6415 - categorical_crossentropy: 1.4975 - top_k_categorical_accuracy: 0.8409 - categorical_hinge: 0.6534
# Epoch 77/100
# 23/23 [==============================] - 7s 281ms/step - loss: 1.4930 - categorical_accuracy: 0.6432 - categorical_crossentropy: 1.4930 - top_k_categorical_accuracy: 0.8418 - categorical_hinge: 0.6509
# Epoch 78/100
# 23/23 [==============================] - 7s 278ms/step - loss: 1.4819 - categorical_accuracy: 0.6446 - categorical_crossentropy: 1.4819 - top_k_categorical_accuracy: 0.8438 - categorical_hinge: 0.6486
# Epoch 79/100
# 23/23 [==============================] - 7s 283ms/step - loss: 1.4723 - categorical_accuracy: 0.6454 - categorical_crossentropy: 1.4723 - top_k_categorical_accuracy: 0.8451 - categorical_hinge: 0.6490
# Epoch 80/100
# 23/23 [==============================] - 7s 283ms/step - loss: 1.4728 - categorical_accuracy: 0.6448 - categorical_crossentropy: 1.4728 - top_k_categorical_accuracy: 0.8426 - categorical_hinge: 0.6471
# Epoch 81/100
# 23/23 [==============================] - 7s 281ms/step - loss: 1.4615 - categorical_accuracy: 0.6493 - categorical_crossentropy: 1.4615 - top_k_categorical_accuracy: 0.8465 - categorical_hinge: 0.6434
# Epoch 82/100
# 23/23 [==============================] - 7s 281ms/step - loss: 1.4518 - categorical_accuracy: 0.6503 - categorical_crossentropy: 1.4518 - top_k_categorical_accuracy: 0.8466 - categorical_hinge: 0.6400
# Epoch 83/100
# 23/23 [==============================] - 7s 280ms/step - loss: 1.4485 - categorical_accuracy: 0.6504 - categorical_crossentropy: 1.4485 - top_k_categorical_accuracy: 0.8481 - categorical_hinge: 0.6414
# Epoch 84/100
# 23/23 [==============================] - 7s 280ms/step - loss: 1.4471 - categorical_accuracy: 0.6510 - categorical_crossentropy: 1.4471 - top_k_categorical_accuracy: 0.8492 - categorical_hinge: 0.6404
# Epoch 85/100
# 23/23 [==============================] - 7s 282ms/step - loss: 1.4424 - categorical_accuracy: 0.6529 - categorical_crossentropy: 1.4424 - top_k_categorical_accuracy: 0.8487 - categorical_hinge: 0.6381
# Epoch 86/100
# 23/23 [==============================] - 7s 282ms/step - loss: 1.4307 - categorical_accuracy: 0.6527 - categorical_crossentropy: 1.4307 - top_k_categorical_accuracy: 0.8516 - categorical_hinge: 0.6373
# Epoch 87/100
# 23/23 [==============================] - 7s 283ms/step - loss: 1.4243 - categorical_accuracy: 0.6547 - categorical_crossentropy: 1.4243 - top_k_categorical_accuracy: 0.8512 - categorical_hinge: 0.6339
# Epoch 88/100
# 23/23 [==============================] - 7s 281ms/step - loss: 1.4284 - categorical_accuracy: 0.6541 - categorical_crossentropy: 1.4284 - top_k_categorical_accuracy: 0.8507 - categorical_hinge: 0.6350
# Epoch 89/100
# 23/23 [==============================] - 7s 284ms/step - loss: 1.4118 - categorical_accuracy: 0.6576 - categorical_crossentropy: 1.4118 - top_k_categorical_accuracy: 0.8527 - categorical_hinge: 0.6295
# Epoch 90/100
# 23/23 [==============================] - 7s 285ms/step - loss: 1.4097 - categorical_accuracy: 0.6589 - categorical_crossentropy: 1.4097 - top_k_categorical_accuracy: 0.8534 - categorical_hinge: 0.6292
# Epoch 91/100
# 23/23 [==============================] - 7s 280ms/step - loss: 1.4068 - categorical_accuracy: 0.6587 - categorical_crossentropy: 1.4068 - top_k_categorical_accuracy: 0.8551 - categorical_hinge: 0.6301
# Epoch 92/100
# 23/23 [==============================] - 7s 286ms/step - loss: 1.3997 - categorical_accuracy: 0.6597 - categorical_crossentropy: 1.3997 - top_k_categorical_accuracy: 0.8546 - categorical_hinge: 0.6278
# Epoch 93/100
# 23/23 [==============================] - 7s 284ms/step - loss: 1.3925 - categorical_accuracy: 0.6608 - categorical_crossentropy: 1.3925 - top_k_categorical_accuracy: 0.8550 - categorical_hinge: 0.6248
# Epoch 94/100
# 23/23 [==============================] - 7s 280ms/step - loss: 1.3842 - categorical_accuracy: 0.6625 - categorical_crossentropy: 1.3842 - top_k_categorical_accuracy: 0.8560 - categorical_hinge: 0.6248
# Epoch 95/100
# 23/23 [==============================] - 7s 285ms/step - loss: 1.3876 - categorical_accuracy: 0.6623 - categorical_crossentropy: 1.3876 - top_k_categorical_accuracy: 0.8558 - categorical_hinge: 0.6234
# Epoch 96/100
# 23/23 [==============================] - 7s 286ms/step - loss: 1.3794 - categorical_accuracy: 0.6644 - categorical_crossentropy: 1.3794 - top_k_categorical_accuracy: 0.8576 - categorical_hinge: 0.6226
# Epoch 97/100
# 23/23 [==============================] - 7s 283ms/step - loss: 1.3772 - categorical_accuracy: 0.6645 - categorical_crossentropy: 1.3772 - top_k_categorical_accuracy: 0.8576 - categorical_hinge: 0.6206
# Epoch 98/100
# 23/23 [==============================] - 7s 285ms/step - loss: 1.3743 - categorical_accuracy: 0.6655 - categorical_crossentropy: 1.3743 - top_k_categorical_accuracy: 0.8583 - categorical_hinge: 0.6210
# Epoch 99/100
# 23/23 [==============================] - 7s 284ms/step - loss: 1.3645 - categorical_accuracy: 0.6677 - categorical_crossentropy: 1.3645 - top_k_categorical_accuracy: 0.8592 - categorical_hinge: 0.6178
# Epoch 100/100
# 23/23 [==============================] - 7s 289ms/step - loss: 1.3568 - categorical_accuracy: 0.6677 - categorical_crossentropy: 1.3568 - top_k_categorical_accuracy: 0.8610 - categorical_hinge: 0.6164

# %%
model_emb.save('../data/lstm_model_emb_13k_batch4k.h5')

# %%
plot_metrics(emb_history, "Evaluation of RNN LSTM model with Embedding ")

# %% [markdown]
# #### **Interpretation:**
# The graphs are trending in the right direction with significant improvement over baseline

# %%
emb_results_df = evaluate_model(emb_baseline_history,  emb_history)

emb_results_df["Model"]= ["Embed LSTM"]*len(emb_results_df)

results_df_merged = results_df.append(emb_results_df)

# save the metric results to file
results_df_merged.to_csv("../data/lstm_results_df_holidays.csv")
# Out:
# total tokens: 289895, distinct tokens: 22567

# %%
# View results
emb_results_df
# Out:
#    max_rows  Actual Rows  batch_size  total_tokens  distinct_tokens  \
# 0     15000        15000        4096        321785            24101
#
#    steps_per_epoch  Baseline Categorical Accuracy  Categorical Accuracy  \
# 0               26                       0.054518              0.801683
#
#    Baseline Categorical Crossentropy  Categorical Crossentropy  \
# 0                           7.198565                  0.741645
#
#    Baseline Top K Categorical Accuracy  Top K Categorical Accuracy       Model
# 0                             0.158597                    0.947463  Embed LSTM

# %% [markdown]
# #### **Interpretation:**
#
# Metrics are much better than baseline
# Top K categorical accuracy of 0.95 is really good, though hard to
# tell if there is overfitting since there is no comparable validation
# data metrics (Keras doesn’t easily support validation data with
# Sequences)

# %%
results_df_merged
# Out:
#    max_rows  Actual Rows  batch_size  total_tokens  distinct_tokens  \
# 0     15000        15000        4096        321785            24101
# 0     15000        15000        4096        321785            24101
#
#    steps_per_epoch  Baseline Categorical Accuracy  Categorical Accuracy  \
# 0               26                       0.054284              0.812021
# 0               26                       0.054518              0.801683
#
#    Baseline Categorical Crossentropy  Categorical Crossentropy  \
# 0                           7.322841                  0.722696
# 0                           7.198565                  0.741645
#
#    Baseline Top K Categorical Accuracy  Top K Categorical Accuracy       Model
# 0                             0.154457                    0.948843        LSTM
# 0                             0.158597                    0.947463  Embed LSTM

# %% [markdown]
# #### **Interpretation:**
#
# Metrics for both models are much better than baseline.
# Both perform similarly

# %%
token2ind, ind2token = text_train.token2ind, text_train.ind2token

input_prefix = 'Sony TV'

text_prefix = ProcessText(input_prefix, token2ind, ind2token)
# Out:
# tokenizing. Going to preprocess...
# In pre-processing

# %%
pred_emb = ModelPredict(model_emb, text_prefix, token2ind, ind2token, max_len, embedding=True)

# %%
temperatures = [1, 0.7, 0.4, 0.1]

for temperature in temperatures:
  print('temperature:', temperature)
  print(pred_emb.generate_sequence(50, temperature=temperature))
  print('\n')
# Out:
# temperature: 1
# Sony TV Mount TV to HDMI TV, Fits Most 80- 120 Miles Range- Full Coverage Slim Built- in- Diamond Black Case for Apple Watch Series4 for Case 44mm 44mm Screen Protector [2- Pack] Soft Silicone Protective Case Cover Built-- Ready 4. 2 Channel
#
#
# temperature: 0.7
# Sony TV and Blu- ray DVD Player BDP 15dBI DVD- 55- 55 LED TV NS Black+Clear+Silver+Gold+Pink for BN59 Customizable- Small SOS Camera Games Compatible with iPhone & Android Wear OS X POY- White Genuine Leather Band Replacement Strap Compatible with Samsung Galaxy Watch 42mm Band, Leelbox
#
#
# temperature: 0.4
# Sony TV- A1 D24H- C1 D24HN S905Y2- Multi-- No Tracker Birthday Gift Children HR, Multi- Way- Proof and Anti- Scratch Shockproof Protective Case for Apple Watch Screen Protector Case, 38mm- Black, Black- Black Optoma Replacement for iWatch Strap Band
#
#
# temperature: 0.1
# Sony TV- A1 D24H-- B1 M422I- B1 P502UI- B1 P502UI- B1 P502UI- B1 P502UI- B1 P502UI- B1 P502UI- B1 P502UI- B1 P502UI- B1 P502UI- B1 P502UI- B1 P502UI- B1 P502UI- B1 P502UI- B1 P502UI-

# %% [markdown]
# #### Inference under the hood
# Dig deep into the calculations of the next word and temperature math. Outputs the top 5 words along with the probabilities to show how temperature affects the next word picked. Look at the probabilities of the possible next words and how temperature determines the selection.

# %%
# Token and ids for the specified Prefix prompt
text_prefix.content, text_prefix.tokens_ind
# Out:
# ('Sony TV', [14751, 15678])

# %%
# prepare the data for .predict
#single_sequence_1 = np.zeros((1, max_len, len(token2ind)), dtype=bool)
#prefix_1 = text_prefix.tokens_ind[-max_len:]

#for i, s in enumerate(prefix_1):
#    single_sequence_1[0, i, s] = 1

# %%
#single_sequence_1[0]

# %%
model_input = np.array(text_prefix.tokens_ind).reshape(1,-1)
model_input[0] # token ids for our input prefix token
# Out:
# array([14751, 15678])

# %%
# Get probabilities of next word for the given input 
prob = model_emb.predict(model_input)[0]
prob # next word probabilities of each of the tokens in vocab
# Out:
# array([5.2308834e-12, 6.1565193e-12, 1.3322315e-11, ..., 3.0114234e-11,
#        3.1707206e-11, 2.9273740e-11], dtype=float32)

# %%
np.sort(prob)[::-1] # see the highest probabiities first
# Out:
# array([3.6129197e-01, 2.8146923e-01, 1.0727139e-01, ..., 3.8881170e-26,
#        3.8556233e-26, 4.9226003e-27], dtype=float32)

# %%
# Set temperatre and get probs
temperature = 1
prob_with_temperature = np.exp(np.where(prob == 0, 0, np.log(prob + 1e-10)) / temperature)

# %%
prob_with_temperature /= np.sum(prob_with_temperature)

# %%
prob_with_temperature
np.sort(prob_with_temperature)[::-1]
# Out:
# array([3.61291200e-01, 2.81468630e-01, 1.07271165e-01, ...,
#        9.99998487e-11, 9.99998487e-11, 9.99998487e-11], dtype=float32)

# %%
# Get 5 random indexes based on probability; NOT the highest probability
next_words = np.random.choice(len(prob_with_temperature), p=prob_with_temperature, size=5)

# %%
# random word (index) chosen based on probability

next_words
# Out:
# array([ 5023, 16658,  5023, 18458, 18458])

# %%
# what was the probability at these indexes? 
prob_with_temperature[next_words] # not bad  - highest probability
# Out:
# array([0.28146863, 0.04583246, 0.28146863, 0.3612912 , 0.3612912 ],
#       dtype=float32)

# %%
# These were the possible next words from which the actual next word was chosen
# convert index back to token (word)

[ ind2token[next_words[i]] for i in range (len(next_words)) ]
# Out:
# ['Mount', 'with', 'Mount', '-', '-']

# %%
# what is the index (and then token) of the highest probability: 0.42082602
#np.where(prob_with_temperature==0.42082602)

# %%
#ind2token[872]

# %% [markdown]
# #### **Interpretation:**
# This is how words are chosen based on the Temperature. Can change Temperature from 1 to other values and see how it affects the word selected.
# Or can put this in a loop (increase the Input prefix with the selected next_word and see how the whole output is generated with the possible options.

# %% [markdown]
# ### Compare with the pre-trained GPT2 model
#
# The original GPT-2 model released by OpenAI was trained on English webpages linked to from Reddit, with a strong bias toward longform content (multiple paragraphs).
# It generates good (coherent) sentences but since it is not tuned for advertisements, it doesn't generate native Amazon ads like our model does.

# %%
# From Hugging Face transformers 

# OpenAI's GPT-2 pre-trained model
gpt2_generator = pipeline("text-generation")
# Out:
# No model was supplied, defaulted to gpt2 (https://huggingface.co/gpt2)
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/523M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %% [markdown]
# ### Compare with EleutherAI's pre-trained GPT-NEO-1.3B model
# It is a GPT2 like causal language model trained on the 800GB
# <a href="https://pile.eleuther.ai/" target="_blank">Pile Dataset</a> (Wikipedia, Common Crawl, GitHub, Stack Exchange, YouTube, Enron emails, PubMed, US Patents, Project Gutenberg and a few more)
#
# Would have liked to use their gpt-j-6B model but it is too resource intensive (25GB to download the pre-trained model weights, 48GB of CPU RAM to just load the model, 96GB of GPU RAM for training/fine-tuning!).
#
# #### Try out various parameters to tune the generated output:
#
# **Greedy search** simply selects the token with the highest probability as its next word.
# However, if we always sample the most likely word, the standard language model training objective causes us to get stuck in loops like “I don’t know. I don’t know. I don’t know.”
#
# **do_sample:** Whether or not to use sampling, use greedy decoding otherwise.
#
# **Temperature, top-k, top-p, repetition_penalty**  (explained below)

# %%
from transformers import pipeline

# %%
# EleutherAI/gpt-neo-1.3B is manageable at 5GB model weights download


gpt_neo_generator = pipeline('text-generation', model='EleutherAI/gpt-neo-1.3B')
# Out:
# Downloading:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.95G [00:00<?, ?B/s]

# %%
s = gpt_neo_generator("Sony TV", do_sample=True, min_length=50)
# View output generated for the input
s[0]['generated_text']

# %% [markdown]
# #### Temperature sampling is inspired by statistical thermodynamics, where high temperature means low energy states are more likely encountered.
# In probability models, logits play the role of energy and we can implement temperature sampling by dividing logits by the temperature before feeding them into softmax and obtaining our sampling probabilities.
#
# •	Low-temperature results in extremely repetitive and predictable text, but where the local structure is highly realistic: in particular, all words (a word being a local pattern of characters) are real words from the corpus.

# %%
s = gpt_neo_generator("Mothers Day discounts for Apple watch", temperature = 0.7, top_p = 0.9, top_k=20)
s[0]['generated_text']

# %% [markdown]
# #### In Top-K sampling, the K most likely next words are filtered and the probability mass is redistributed among only those K next words.
# #### To apply the Top-k sampling, all the tokens are sorted according to the probabilities and the probabilities for anything below the k’th token are zeroed out.

# %%
gpt_neo_generator("Apple Watch", temperature = 0.7, top_k=20)

# %% [markdown]
# #### Top-P Sampling (Nucleus sampling): Another way to exclude very low probability tokens is to include the most probable tokens that make up the “nucleus” of the probability mass function (PMF), such that the sum of the most probable tokens just reaches p. In other words, based on a parameter 0<=p<=1, Top-P Sampling aggregates the smallest set of words that have summed probability mass p. It can be thought of as a variation of top-k sampling with dynamic k.

# %%
gpt_neo_generator("Best deals on Samsung", temperature = 0.7, top_p = 0.9)

# %% [markdown]
# #### repetition_penalty
# The more a token is used within generation the more it is penalized to not be picked in successive generation passes.

# %%
gpt_neo_generator("Best deals on Samsung", temperature = 0.7, top_p = 0.9, top_k=20, repetition_penalty=3.0)

# %%
# Compare with GPT-2
gpt2_generator("Apple Watch", temperature = 0.7, top_p = 0.9, top_k=20, repetition_penalty=3.0)

# %%
# num_return_sequences causes multiple outputs to be generated

gpt2_generator("AmazonBasics", temperature = 0.7, top_p = 0.9, top_k=20, repetition_penalty=3.0, num_return_sequences=3)

# %% [markdown]
# ### Ooh, check this out!

# %%
# Download my fine-tuned model which is published to HuggingFace! 

ad_text_generator = pipeline('text-generation', model='nirajsaran/AdTextGenerator')
# Out:
# Downloading:   0%|          | 0.00/1.07k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/526M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/561 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/779k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/435 [00:00<?, ?B/s]

# %%
# Do inference! This performs faster than my in-memory trained model! 
# And it supports all the additional parameters, including those not available through the GUI on the HuggingFace site: 
# https://huggingface.co/nirajsaran/AdTextGenerator

ad_text_generator("Last minute Christmas deals on Sony TV", do_sample = True, temperature=0.8, top_p = 0.9, top_k=5, repetition_penalty=3.0, num_return_sequences=3)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Last minute Christmas deals on Sony TV HDTV XBOX'},
#  {'generated_text': 'Last minute Christmas deals on Sony TV'},
#  {'generated_text': 'Last minute Christmas deals on Sony TV, Package with HDMI and AV Cable'}]

# %% [markdown]
# #### **Interpretation**:
# The Large Language Models like GPT-2 and GPT_NEO etc do really well on the text they're trained on, with zero-shot learning.
# However, they are not suitable for my use case of generating the text for advertisements in the format that Amazon ads typically have.
#
# They do claim to have "few-shot learning", where you can provide prompts in a line or two and it learns from this minimal training data to generate similar output content. I have not found it generate ad text, especialy for Amazon ads.
#
# My fine-tuned model works quite well on the Electronics and Wearables categories on which it has been fine-tuned. There are, however, occasional hallucinations, though the ad copy is mostly coherent.
#
# In other domains, it doesn't do quite as well...
# Tesla for Christmas today
# Honda on sale
#
# The last area to try out is to fine-tune these pre-trained models with my dataset i.e. the pre-trained model is trained via repeated graident updates at the end of each epoch using a largish corpus of example texts. This involves updating the weights of a pre-trained model by training on a supervised dataset specific to the desired task of generating ad text for Amazon.
#
# **This is done in the next notebook**
# fine_tune_pretrained_model_for_ad_generation.ipynb

# %% [markdown]
# ### End of notebook
